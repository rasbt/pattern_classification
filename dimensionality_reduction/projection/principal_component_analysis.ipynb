# %% [markdown]
# # Introduction

# %% [markdown]
# With the principal component analysis of our feature space our goal here is to define an "optimal" subspace to represent our data. For example, if we want to reduce the computational costs and parameter estimation errors in a pattern classification problem, we can use PCA to reduce the number of dimensions of our feature space by extracting a subspace that describes our data "best".
#
# ###Principal Component Analysis (PCA) Vs. Multiple Discriminant Analysis (MDA)
# Both linear transformation methods Multiple Discriminant Analysis (MDA) and Principal Component Analysis (PCA) are closely related. In PCA, we are interested to find the directions (components) that maximize the variance in our dataset, where in MDA, we are additionally interested to find the directions that maximize the separation of different classes (for example, in pattern classification problems where our dataset consists of multiple classes. Note that PCA ignores class labels).
# ***In other words, in PCA, we are projecting the entire set of data (without class labels) onto a different subspace, and in MDA, we are trying to determine a suitable subspace to distinguish between patterns that belong to different classes. ***
# In typical pattern recognition problems, a PCA is often followed by an MDA.
#
# #### What is a "good" subspace?
# Let's assume that our goal is to reduce the dimensions of a $x$-dimensional dataset by projecting it onto a $(x-k)$-dimensional subspace. So, how do we know what a good subspace is, and what size we should choose for $k$?
# Later, we will compute eigenvectors (the components) and collect them in a so-called scatter-matrix. Each of those eigenvectors is associated with its corresponding eigenvalue, where the eigenvalues tell us about the "length" of the eigenvectors. If we observe that all the eigenvalues are of very similar magnitude, this is a good indicator that our data is already in a "good" subspace. Or if some of the eigenvalues are much much higher than others, we can ...

# %% [markdown]
# ### Summarizing the PCA approach
# 1. <a href="#drop_labels"> Take the whole dataset consisting of $d$-dimensional samples and ignore the class labels</a>
# 2. <a href="#mean_vec"> Compute the $d$-dimensional mean vector (i.e., the means for every dimension of the whole dataset)</a>
# 3. Compute the covariance matrix of the whole data set
# 4. Compute eigenvectors ($\pmb e_1, \; \pmb e_2, \; ..., \; \pmb e_d $) and corresponding eigenvalues ($\pmb \lambda_1, \; \pmb \lambda_2, \; ..., \; \pmb \lambda_d$) and sort these eigenvectors by decreasing eigenvalue
# 5. Choose $k$ eigenvectors with the largest eigenvalues and form a $d \times k $ dimensional matrix $\pmb W$(where every column represents an eigenvector)
# 6. Use this $d \times k $ eigenvector matrix to transform the samples onto the new subspace. This can be summarized by the mathematical equation: $\pmb y = \pmb W^T \times \pmb x$ (where $\pmb x$ is a $d \times 1$-dimensional vector representing one sample, and $\pmb y$ is the transformed $k \times 1$-dimensional sample in the new subspace.

# %% [markdown]
# # Generating some 3-dimensional sample data

# %% [markdown]
# We create two $3\times20$ datasets - one dataset for each class $\omega_1$ and $\omega_2$ - where each column can be pictured as a 3-dimensional vector $\pmb x = \begin{pmatrix} x_1 \\ x_2 \\ x_3 \end{pmatrix}$

# %%
np.random.seed(234234782384239784) # random seed for consistency
import numpy as np

mu_vec1 = np.array([0,0,0])
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20).T
assert class1_sample.shape == (3,20), "The matrix has not the dimensions 3x20"

mu_vec2 = np.array([1,1,1])
cov_mat2 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class2_sample = np.random.multivariate_normal(mu_vec2, cov_mat2, 20).T
assert class1_sample.shape == (3,20), "The matrix has not the dimensions 3x20"

# %%
# %pylab inline
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
mpl.rcParams['legend.fontsize'] = 10   
ax.plot(class1_sample[0,:], class1_sample[1,:], class1_sample[2,:], 'o', markersize=8, color='blue', alpha=0.5, label='class1')
ax.plot(class2_sample[0,:], class2_sample[1,:], class2_sample[2,:], '^', markersize=8, alpha=0.5, color='red', label='class2')

plt.title('Samples for class 1 and class 2')
ax.legend(loc = 'upper right')
plt.draw()


plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <a name='drop_labels'></a>
#
# #1. Take the whole dataset consisting of d-dimensional samples and ignore the class labels
#
# Because we don't need class labels for the PCA analysis, let us merge the samples for our 2 classes into one $3\times40$-dimensional array.

# %%
all_samples = np.concatenate((class1_sample, class2_sample), axis=1)
assert all_samples.shape == (3,40), "The matrix has not the dimensions 3x40"

# %% [markdown]
# <a name='mean_vec'></a>
# #2. Compute the d-dimensional mean vector

# %%
mean_x = np.mean(all_samples[0,:])
mean_y = np.mean(all_samples[1,:])
mean_z = np.mean(all_samples[2,:])

mean_vector = np.array([[mean_x],[mean_y],[mean_z]])

print('Mean Vector:\n', mean_vector)
# Out:
# Mean Vector:
#  [[ 0.50576644]
#  [ 0.30186591]
#  [ 0.76459177]]

# %% [markdown]
# # Eigenvectors from Scatter Matrix

# %% [markdown]
# The scatter matrix is computed by the following equation:
# $S = \sum\limits_{k=1}^n (\pmb x_k - \pmb m)\;(\pmb x_k - \pmb m)^T$
# where $\pmb m$ is the mean vector
# $\pmb m = \frac{1}{n} \sum\limits_{k=1}^n \; \pmb x_k$

# %%
scatter_matrix = np.zeros((3,3))
for i in range(all_samples.shape[1]):
    scatter_matrix += (all_samples[:,i].reshape(3,1) - mean_vector).dot((all_samples[:,i].reshape(3,1) - mean_vector).T)
print('Scatter Matrix:\n', scatter_matrix)

eig_val, eig_vec = np.linalg.eig(scatter_matrix)
for i in range(len(eig_val)):
    eigv = eig_vec[:,i].reshape(1,3).T
    print('Eigenvector {}: \n{}'.format(i+1, eigv))
    print('Eigenvalue {}: {}'.format(i+1, eig_val[i]))
    print(40 * '-')
# Out:
# Scatter Matrix:
#  [[ 48.91593255   7.11744916   7.20810281]
#  [  7.11744916  37.92902984   2.7370493 ]
#  [  7.20810281   2.7370493   35.6363759 ]]
# Eigenvector 1:
# [[-0.84190486]
#  [-0.39978877]
#  [-0.36244329]]
# Eigenvalue 1: 55.398855957302445
# ----------------------------------------
# Eigenvector 2:
# [[-0.44565232]
#  [ 0.13637858]
#  [ 0.88475697]]
# Eigenvalue 2: 32.42754801292286
# ----------------------------------------
# Eigenvector 3:
# [[ 0.30428639]
#  [-0.90640489]
#  [ 0.29298458]]
# Eigenvalue 3: 34.65493432806495
# ----------------------------------------

# %% [markdown]
# #Eigenvectors from Covariance Matrix

# %%
cov_mat = np.cov([samples[0,:],samples[1,:],samples[2,:]])
print('Covariance Matrix:\n', cov_mat)

eig_val, eig_vec = np.linalg.eig(cov_mat)
for i in range(len(eig_val)):
    eigv = eig_vec[:,i].reshape(1,3).T
    print('Eigenvector {}: \n{}'.format(i+1, eigv))
    print('Eigenvalue {}: {}'.format(i+1, eig_val[i]))
    print(40 * '-')
# Out:
# Covariance Matrix:
#  [[ 1.25425468  0.1824987   0.18482315]
#  [ 0.1824987   0.97253923  0.07018075]
#  [ 0.18482315  0.07018075  0.91375323]]
# Eigenvector 1:
# [[-0.84190486]
#  [-0.39978877]
#  [-0.36244329]]
# Eigenvalue 1: 1.4204834860846791
# ----------------------------------------
# Eigenvector 2:
# [[-0.44565232]
#  [ 0.13637858]
#  [ 0.88475697]]
# Eigenvalue 2: 0.8314755900749456
# ----------------------------------------
# Eigenvector 3:
# [[ 0.30428639]
#  [-0.90640489]
#  [ 0.29298458]]
# Eigenvalue 3: 0.8885880596939733
# ----------------------------------------
