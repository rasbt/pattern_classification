# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, random_state=123)

plt.figure(figsize=(8,6))

plt.scatter(X[y==0, 0], X[y==0, 1], color='red')
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue')

plt.title('A nonlinear 2Ddataset')
plt.ylabel('y coordinate')
plt.xlabel('x coordinate')

plt.show()
# Out:
# /Users/sebastian/miniconda3/envs/py34/lib/python3.4/site-packages/sklearn/datasets/samples_generator.py:612: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = np.hstack([np.zeros(n_samples_in, dtype=np.intp),

# %% [markdown]
# \begin{equation} K(\pmb{x_i, x_j}) = exp\bigg(- \gamma \; \lVert\pmb{x_i - x_j }\rVert^{2}_{2} \bigg)\end{equation}

# %% [markdown]
# Where $\gamma$ is a free parameter $\textstyle\gamma = \tfrac{1}{2\sigma^2}$
#
# Radial Basis Function (RBF) Kernel:
# \begin{equation} K(\pmb{x_i, x_j}) = exp\Bigg( - \frac{\lVert\pmb{x_i - x_j }\rVert^{2}_{2}}{2\sigma^2} \Bigg)\end{equation}
#
# where $\lVert\pmb{x_i - x_j }\rVert^{2}_{2} = \Sigma_j(\pmb{x_{ik} - x_{jk} })^2$ is the squared Euclidean distance between two data points, $\pmb{x_i}$ and $\pmb{x_j}$. $\sigma^2$ is the variance of the
# Euclidean distance between all pairs of data points.

# %%
from sklearn.decomposition import KernelPCA

scikit_kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_skernpca = scikit_kpca.fit_transform(X)

plt.figure(figsize=(8,6))
plt.scatter(X_skernpca[y==0, 0], X_skernpca[y==0, 1], color='red')
plt.scatter(X_skernpca[y==1, 0], X_skernpca[y==1, 1], color='blue')

plt.title('First 2 components after RBF Kernel PCA')
plt.show()

# %%
import numpy as np
scikit_kpca = KernelPCA(n_components=1, kernel='rbf', gamma=15)
X_skernpca = scikit_kpca.fit_transform(X)

plt.figure(figsize=(8,6))
plt.scatter(X_skernpca[y==0, 0], np.zeros((50,1)), color='red', alpha=0.5)
plt.scatter(X_skernpca[y==1, 0], np.zeros((50,1)), color='blue', alpha=0.5)

plt.title('First component after RBF Kernel PCA')
plt.show()

# %%
from sklearn.preprocessing import KernelCenterer
from scipy.spatial.distance import pdist, squareform
from scipy import exp
from scipy.linalg import eigh


# pdist to calculate the squared Euclidean distances for every pair of points
# in the 100x2 dimensional dataset.
sq_dists = pdist(X, 'sqeuclidean')

# Variance of the Euclidean distance between all pairs of data points.
variance = np.var(sq_dists)

# squareform to converts the pairwise distances into a symmetric 100x100 matrix
mat_sq_dists = squareform(sq_dists)

# set the gamma parameter equal to the one I used in scikit-learn KernelPCA
gamma = 1/(2*variance)

# Compute the 100x100 kernel matrix
K = exp(-gamma * mat_sq_dists)

# Center the kernel matrix
kern_cent = KernelCenterer()
K = kern_cent.fit_transform(K)

# Sparsify
for row in A:
    sort_idx = np.argsort(row)[::-1] # get indexes of sort order (high to low)
    for i in sort_idx[10:]:
        row[i]=0

    
# Get eigenvalues in ascending order with corresponding 
# eigenvectors from the symmetric matrix
eigvals, eigvecs = eigh(K)

# Get the eigenvectors that corresponds to the highest eigenvalue
X_pc1 = eigvecs[:,-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-60709ca22a5a> in <module>()
#      26
#      27 # Sparsify
# ---> 28 for row in A:
#      29     sort_idx = np.argsort(row)[::-1] # get indexes of sort order (high to low)
#      30     for i in sort_idx[10:]:
#
# NameError: name 'A' is not defined

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pc1[y==0], np.zeros((50,1)), color='red', alpha=0.5)
plt.scatter(X_pc1[y==1], np.zeros((50,1)), color='blue', alpha=0.5)

plt.title('First component after RBF Kernel PCA')
plt.show()

# %%
X_pc1.shape
# Out:
# (100,)
