# %% [markdown]
# Sebastian Raschka
# Last updated: 04/12/2014
# <hr>

# %% [markdown]
# # Sections
# - [1)](#task_1)
#     - [Description of task 1](#descr_task_1)
#     - [About the dataset](#about_data)
#     - [Reading in and analyzing the dataset](#reading_data)
#     - [Dividing the dataset radomly in training (70%) and test (30%) sets](#divide_data)
#     - [Visualizing the 3 classes in a scatter plot](#viz_div_data)
#     - [1 a)](#task_1a)
#         - [Description of task 1 a)](#descr_task_1a)
#         - [Discriminant Functions](#discr_func)
#         - [Decision Boundaries](#decision_boundaries)
#         - [Implementing the Discriminant Function for arbitrary covariance matrices](#impl_discrfunc)
#         - [Implementing the descision rule](#decision_rule)
#         - [Classifying data and calculating the empirical error](#empirical_error)
#             - [Empirical error of the training dataset](#emp_err_train)
#             - [Empirical error of the test dataset](#emp_err_test)
#     - [1 b)](#task_1b)
#         - [Description of task 1 b)](#descr_task_1b)
#         - [About the Maximum Likelihood Estimate (MLE)](#about_mle)
#         - [MLE of the mean vector $\pmb\mu$](#mle_mu)
#         - [MLE of the covariance matrix $\pmb\Sigma$](#mle_sigma)
#         - [Error on the test set using the estimated parameters](#error_mle)
#     - [1 c)](#task_1c)
#         - [Description of task 1 c)](#description_1c)
#         - [Implementing the classifier using  Bayes' decision rule](#bayes_rule_parzen)
#         - [Error on the test set using the likelihoods from the Gaussian kernel estimate of the Parzen-window technique](#error_parzen)
#         - [Using the Parzen-window technique for Gaussian kernel desnity estimation](#use_parzen)
#     - [1 e)](#task_1e)
#         - [Description of task 1 e)](#description_1e)
#         - [Creating training sets with variable size](#shrink_train)
#         - [MLE error rate for varying training set sizes](#mle_varying)
#         - [Error rate of kernel density estimaton via Parzen-window for varying training sizes](#parzen_varying)
#         - [Error rate of the k-nearest-neighbor technique for varying training sizes](#k_nearest_error)
#         - [Plotting the error rate as a function of the size of the training set for each of the 3 cases](#plot_error_func)

# %%
import numpy as np

np.random.seed(1234568)

# %% [markdown]
# <a name="task_1"></a>
# # 1)
# <a name="descr_task_1"></a>
# ### Description of Task 1):
# [65 points] Consider the dataset available here: [project_data.txt](./data/project_data.txt). It consists of two-dimensional patterns, $\pmb{x} = [x_1, x_2]^t$ , pertaining to 3 classes $(\omega_1,\omega_2,\omega_3)$. The feature values are indicated in the first two columns while the class labels are specified in the last column. The priors of all 3 classes are the same. Randomly partition this dataset into a training set (70% of each class) and a test set (30% of each class).

# %% [markdown]
# <a name="about_data"></a>
# ### About the dataset

# %% [markdown]
# The data set consists of 1500 rows and 3 columns, where
# - column 1: $x_1$ values
# - column 2: $x_2$ values
# - column 3: class labels
#
# **Excerpt from the dataset: **
# <code>    1.8569 -3.4702 1
#     -0.2096 -2.8342 1
#     -1.0265 2.1614 1
#     [...]
#     9.3851 4.0336 2
#     10.1375 1.1495 2
#     11.7569 0.8005 2
#     [...]
#     3.9854 5.1360 3
#     2.7592 5.9536 3
#     4.1379 4.3258 3
#     [...]  </code>

# %% [markdown]
# <a name="reading_data"></a>
# ### Reading in and analyzing the dataset

# %%
import numpy as np

all_projdata = np.genfromtxt('./data/project_data.txt', delimiter=' ')

# Test if the data is read in in the correct dimensions:
assert(all_projdata.shape == (1500, 3))
assert(all_projdata[all_projdata[:,2] == 1].shape == (500,3))
assert(all_projdata[all_projdata[:,2] == 2].shape == (500,3))
assert(all_projdata[all_projdata[:,2] == 3].shape == (500,3))

# Print min and max values of the 2 dimensions:
print("Range of x_1: ({}, {})".format(min(all_projdata[:,0]), max(all_projdata[:,0])))
print("Range of x_2: ({}, {})".format(min(all_projdata[:,1]), max(all_projdata[:,1])))
# Out:
# Range of x_1: (-6.8114, 17.4559)
# Range of x_2: (-7.9943, 11.9156)

# %% [markdown]
# <a name="divide_data"></a>
# ### Dividing the dataset radomly in training (70%) and test (30%) sets

# %%
# Accomodation, since numpy arrays cannot be empty
test_set = np.zeros(shape=(1,3))
train_set = np.zeros(shape=(1,3))

#np.random.shuffle(all_projdata)

for i in range(0,3):
    cl_shuffle = np.copy(all_projdata[all_projdata[:,2] == i+1])
    np.random.shuffle(cl_shuffle)
    test_set = np.append(test_set, cl_shuffle[0:150,:], axis=0)
    train_set = np.append(train_set, cl_shuffle[150:,:], axis=0)
                                  
# delete the first placeholder row used for initializing the array                                  
test_set = np.delete(test_set, 0, axis=0)
train_set = np.delete(train_set, 0, axis=0)

assert(test_set.shape == (1500*0.3,3))
assert(train_set.shape == (1500*0.7,3))

# %% [markdown]
# <a name="viz_div_data"></a>
# ### Visualizing the 3 classes in a scatter plot

# %%
# %pylab inline

import numpy as np
from matplotlib import pyplot as plt

# Test Dataset
f, ax = plt.subplots(figsize=(7, 7))
ax.scatter(test_set[test_set[:,2] == 1][:,0], test_set[test_set[:,2] == 1][:,1], \
           marker='o', color='green', s=40, alpha=0.5, label='$\omega_1$')
ax.scatter(test_set[test_set[:,2] == 2][:,0], test_set[test_set[:,2] == 2][:,1], \
           marker='^', color='red', s=40, alpha=0.5, label='$\omega_2$')
ax.scatter(test_set[test_set[:,2] == 3][:,0], test_set[test_set[:,2] == 3][:,1], \
           marker='s', color='blue', s=40, alpha=0.5, label='$\omega_3$')
plt.legend(loc='upper right') 
plt.title('Test Dataset', size=20)
plt.ylabel('$x_2$', size=20)
plt.xlabel('$x_1$', size=20)
plt.show()

# Training Dataset
f, ax = plt.subplots(figsize=(7, 7))
ax.scatter(train_set[train_set[:,2] == 1][:,0], train_set[train_set[:,2] == 1][:,1], \
           marker='o', color='green', s=40, alpha=0.5, label='$\omega_1$')
ax.scatter(train_set[train_set[:,2] == 2][:,0], train_set[train_set[:,2] == 2][:,1], \
           marker='^', color='red', s=40, alpha=0.5, label='$\omega_2$')
ax.scatter(train_set[train_set[:,2] == 3][:,0], train_set[train_set[:,2] == 3][:,1], \
           marker='s', color='blue', s=40, alpha=0.5, label='$\omega_3$')
plt.legend(loc='upper right') 
plt.title('Training Dataset', size=20)
plt.ylabel('$x_2$', size=20)
plt.xlabel('$x_1$', size=20)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <a name="task_1a"></a>
# # 1a)
#
# <a name="descr_task_1a"></a>
#
#
# Let
#
# $p([x_1, x_2]^t |\omega_1) ∼ N([0,0]^t,4I), \\
# p([x_1, x_2]^t |\omega_2) ∼ N([10,0]^t,4I), \\
# p([x_1, x_2]^t |\omega_3) ∼ N([5,5]^t,5I),$
#
# where $I$ is the $2 \times 2$ identity matrix. What is the error rate on the test set when the Bayesian decision rule is employed for classification?

# %% [markdown]
# ### Bayes' Rule:
#
#
# $ P(\omega_j|x) = \frac{p(x|\omega_j) * P(\omega_j)}{p(x)}$
#
# with **prior probabilities**: $P(\omega_1) \; = P(\omega_2) \; = P(\omega_3)\; = \frac{1}{3}$

# %% [markdown]
# <a name="discr_func"></a>
# ### Discriminant Functions:
#
# The **objective function** is to maximize the discriminant function, which we define as the posterior probability here to perform a **minimum-error classification** (Bayes classifier).
#
# $ g_1(\pmb x) = P(\omega_1 | \; \pmb{x}), \quad  g_2(\pmb{x}) = P(\omega_2 | \; \pmb{x}), \quad  g_3(\pmb{x}) = P(\omega_2 | \; \pmb{x})$
#
# $ \Rightarrow g_1(\pmb{x}) = P(\pmb{x}\;|\;\omega_1) \;\cdot\; P(\omega_1) \quad | \; ln \\
# \quad g_2(\pmb x) = P(\pmb{x}\;|\;\omega_2) \;\cdot\; P(\omega_2) \quad | \; ln \\
# \quad g_3(\pmb x) = P(\pmb{x}\;|\;\omega_3) \;\cdot\; P(\omega_3) \quad | \; ln$

# %% [markdown]
# We can drop the prior probabilities (since we have equal priors in this case):
#
# $ \Rightarrow g_1(\pmb{x}) = ln(P(\pmb{x}\;|\;\omega_1))  \\
# \quad g_2(\pmb{x}) = ln(P(\pmb{x}\;|\;\omega_2)) \\
# \quad g_3(\pmb{x}) = ln(P(\pmb{x}\;|\;\omega_3))$

# %% [markdown]
# The equations for the general multivariate normal case with arbitrary covariance matrices (i.e., different covariance matrices for each case):

# %% [markdown]
# $ \Rightarrow g_1(\pmb{x}) = \pmb{x}^{\,t} \bigg( - \frac{1}{2} \Sigma_1^{-1} \bigg) \pmb{x} + \bigg( \Sigma_1^{-1} \pmb{\mu}_{\,1}\bigg)^t \pmb x + \bigg( -\frac{1}{2} \pmb{\mu}_{\,1}^{\,t}  \Sigma_{1}^{-1} \pmb{\mu}_{\,1} -\frac{1}{2} ln(|\Sigma_1|)\bigg)   \\
# \quad g_2(\pmb{x}) = \pmb{x}^{\,t} \bigg( - \frac{1}{2} \Sigma_2^{-1} \bigg) \pmb{x} + \bigg( \Sigma_2^{-1} \pmb{\mu}_{\,2}\bigg)^t \pmb x + \bigg( -\frac{1}{2} \pmb{\mu}_{\,2}^{\,t} \Sigma_{2}^{-1} \pmb{\mu}_{\,2} -\frac{1}{2} ln(|\Sigma_2|)\bigg) \\
# \quad g_3(\pmb{x}) = \pmb{x}^{\,t} \bigg( - \frac{1}{2} \Sigma_3^{-1} \bigg) \pmb{x} + \bigg( \Sigma_3^{-1} \pmb{\mu}_{\,3}\bigg)^t \pmb x + \bigg( -\frac{1}{2} \pmb{\mu}_{\,3}^{\,t} \Sigma_{3}^{-1} \pmb{\mu}_{\,3} -\frac{1}{2} ln(|\Sigma_3|)\bigg)$

# %% [markdown]
# <hr>
# **Let:**
#
# $\pmb{W}_{i} = - \frac{1}{2} \Sigma_i^{-1}\\
# \pmb{w}_i = \Sigma_i^{-1} \pmb{\mu}_{\,i}\\
# \omega_{i0} = \bigg( -\frac{1}{2} \pmb{\mu}_{\,i}^{\,t}\; \Sigma_{i}^{-1} \pmb{\mu}_{\,i} -\frac{1}{2} ln(|\Sigma_i|)\bigg)$
# <hr>

# %% [markdown]
# $ \pmb{W}_{1} = \bigg[
# \begin{array}{cc}
# -(1/8) & 0\\
# 0 & -(1/8) \\
# \end{array} \bigg] $

# %% [markdown]
# $ \pmb{w}_{1} = \bigg[
# \begin{array}{cc}
# (1/4) & 0\\
# 0 & (1/4) \\
# \end{array} \bigg] \cdot \bigg[
# \begin{array}{c}
# 0 \\
# 0 \\
# \end{array} \bigg] = \bigg[
# \begin{array}{c}
# 0 \\
# 0 \\
# \end{array} \bigg]$

# %% [markdown]
# $ \omega_{10} = -\frac{1}{2} [0 \quad 0 ] \bigg[
# \begin{array}{cc}
# (1/4) & 0\\
# 0 & (1/4) \\
# \end{array} \bigg] \cdot \bigg[
# \begin{array}{c}
# 0 \\
# 0 \\
# \end{array} \bigg]
# - ln(4) = -ln(4)$

# %% [markdown]
# with $ \quad g_1(\pmb{x}) = \pmb{x}^{\,t} \bigg( - \frac{1}{2} \Sigma_1^{-1} \bigg) \pmb{x} + \bigg( \Sigma_1^{-1} \pmb{\mu}_{\,1}\bigg)^t \pmb x + \bigg( -\frac{1}{2} \pmb{\mu}_{\,1}^{\,t}  \Sigma_{1}^{-1} \pmb{\mu}_{\,1} -\frac{1}{2} ln(|\Sigma_1|)\bigg) $

# %% [markdown]
# $ \Rightarrow g_1(\pmb{x}) = \pmb{x}^{t}  \bigg[
# \begin{array}{cc}
# -(1/8) & 0\\
# 0 & -(1/8) \\
# \end{array} \bigg] \pmb{x} + [0 \quad 0 ] \; \pmb x - ln(4)
# = \pmb{x}^{t} (-\frac{1}{8} \; \pmb{x}) - 2ln(2) $
#
# $ \Rightarrow g_1(\pmb{x}) = - \frac{1}{8} (x^{2}_1 + x^{2}_2 ) - 2ln(2)$

# %% [markdown]
# <hr>

# %% [markdown]
# $ \pmb{W}_{2} = \bigg[
# \begin{array}{cc}
# -(1/8) & 0\\
# 0 & -(1/8) \\
# \end{array} \bigg] $

# %% [markdown]
# $ \pmb{w}_{2} = \bigg[
# \begin{array}{cc}
# (1/4) & 0\\
# 0 & (1/4) \\
# \end{array} \bigg] \cdot \bigg[
# \begin{array}{c}
# 10 \\
# 0 \\
# \end{array} \bigg] = \bigg[
# \begin{array}{c}
# 2.5 \\
# 0 \\
# \end{array} \bigg]$

# %% [markdown]
# $ \omega_{20} = -\frac{1}{2} [10 \quad 0 ] \bigg[
# \begin{array}{cc}
# (1/4) & 0\\
# 0 & (1/4) \\
# \end{array} \bigg] \cdot \bigg[
# \begin{array}{c}
# 10 \\
# 0 \\
# \end{array} \bigg]
# - ln(4) = -12.5-ln(4)$

# %% [markdown]
# with $ \quad g_2(\pmb{x}) = \pmb{x}^{\,t} \bigg( - \frac{1}{2} \Sigma_2^{-1} \bigg) \pmb{x} + \bigg( \Sigma_2^{-1} \pmb{\mu}_{\,2}\bigg)^t \pmb x + \bigg( -\frac{1}{2} \pmb{\mu}_{\,2}^{\,t} \Sigma_{2}^{-1} \pmb{\mu}_{\,2} -\frac{1}{2} ln(|\Sigma_2|)\bigg) $

# %% [markdown]
# $ \Rightarrow g_2(\pmb{x}) = \pmb{x}^{t}  \bigg[
# \begin{array}{cc}
# -(1/8) & 0\\
# 0 & -(1/8) \\
# \end{array} \bigg] \pmb{x} + [2.5 \quad 0 ]\;\pmb x - 12.5 - ln(4)
# = \pmb{x}^{t} \cdot( -\frac{1}{8} \; \pmb{x}) + 2.5 x_1 - 12.5 - 2ln(2) $
#
# $ \Rightarrow g_2(\pmb{x}) = - \frac{1}{8} (x^{2}_1 + x^{2}_2) +2.5 x_1 - 12.5 - 2ln(2)$

# %% [markdown]
# <hr>

# %% [markdown]
# $ \pmb{W}_{3} = \bigg[
# \begin{array}{cc}
# -(1/10) & 0\\
# 0 & -(1/10) \\
# \end{array} \bigg] $

# %% [markdown]
# $ \pmb{w}_{3} = \bigg[
# \begin{array}{cc}
# (1/5) & 0\\
# 0 & (1/5) \\
# \end{array} \bigg] \cdot \bigg[
# \begin{array}{c}
# 5 \\
# 5 \\
# \end{array} \bigg] = \bigg[
# \begin{array}{c}
# 1 \\
# 1 \\
# \end{array} \bigg]$

# %% [markdown]
# $ \omega_{30} = -\frac{1}{2} [5 \quad 5 ] \bigg[
# \begin{array}{cc}
# (1/5) & 0\\
# 0 & (1/5) \\
# \end{array} \bigg] \cdot \bigg[
# \begin{array}{c}
# 5 \\
# 5 \\
# \end{array} \bigg]
# - ln(5) = 5 -ln(5)$

# %% [markdown]
# with $ \quad g_3(\pmb{x}) = \pmb{x}^{\,t} \bigg( - \frac{1}{2} \Sigma_3^{-1} \bigg) \pmb{x} + \bigg( \Sigma_3^{-1} \pmb{\mu}_{\,3}\bigg)^t \pmb x + \bigg( -\frac{1}{2} \pmb{\mu}_{\,3}^{\,t} \Sigma_{3}^{-1} \pmb{\mu}_{\,3} -\frac{1}{2} ln(|\Sigma_3|)\bigg)$

# %% [markdown]
# $ \Rightarrow g_3(\pmb{x}) = \pmb{x}^{t}  \bigg[
# \begin{array}{cc}
# -(1/10) & 0\\
# 0 & -(1/10) \\
# \end{array} \bigg] \pmb{x} + [1 \quad 1 ]\; \pmb x + 5 - ln(5)
# = \pmb{x}^{t} \cdot ( - \frac{1}{10})\; \pmb x )+  \; {x_1} + {x_2} + 5 - ln(5) $
#
# $ \Rightarrow g_3(\pmb{x}) = - \frac{1}{10} (x^{2}_1 + x^{2}_2)+  \; {x_1} + {x_2} + 5 - ln(5)$

# %% [markdown]
# <a name='decision_boundaries'></a>
# ### Decision Boundaries

# %% [markdown]
# $ g_1(\pmb x) = g_2(\pmb x) \\
# \Rightarrow g_1(\pmb x) - g_2(\pmb x) = 0 \\
# \Rightarrow 12.5 - 2.5x_1 = 0 \\
# \Rightarrow x_1 = 5$

# %% [markdown]
# <a name='impl_discrfunc'></a>
# ### Implementing the Discriminant Function for arbitrary covariance matrices

# %%
def discriminant_function(x_vec, cov_mat, mu_vec):
    """
    Calculates the value of the discriminant function for a dx1 dimensional
    sample given the covariance matrix and mean vector.
    
    Keyword arguments:
        x_vec: A dx1 dimensional numpy array representing the sample.
        cov_mat: numpy array of the covariance matrix.
        mu_vec: dx1 dimensional numpy array of the sample mean.
    
    Returns a float value as result of the discriminant function.
    
    """
    W_i = (-1/2) * np.linalg.inv(cov_mat)
    assert(W_i.shape[0] > 1 and W_i.shape[1] > 1), 'W_i must be a matrix'
    
    w_i = np.linalg.inv(cov_mat).dot(mu_vec)
    assert(w_i.shape[0] > 1 and w_i.shape[1] == 1), 'w_i must be a column vector'
    
    omega_i_p1 = (((-1/2) * (mu_vec).T).dot(np.linalg.inv(cov_mat))).dot(mu_vec)
    omega_i_p2 = (-1/2) * np.log(np.linalg.det(cov_mat))
    omega_i = omega_i_p1 - omega_i_p2
    assert(omega_i.shape == (1, 1)), 'omega_i must be a scalar'
    
    g = ((x_vec.T).dot(W_i)).dot(x_vec) + (w_i.T).dot(x_vec) + omega_i
    return float(g)

# %% [markdown]
# <a name='decision_rule'></a>
# ### Implementing the decision rule

# %%
import operator

def classify_data(x_vec, g, mu_vecs, cov_mats):
    """
    Classifies an input sample into 1 out of 3 classes determined by
    maximizing the discriminant function g_i().
    
    Keyword arguments:
        x_vec: A dx1 dimensional numpy array representing the sample.
        g: The discriminant function.
        mu_vecs: A list of mean vectors as input for g.
        cov_mats: A list of covariance matrices as input for g.
    
    Returns a tuple (g_i()_value, class label).
    
    """
    assert(len(mu_vecs) == len(cov_mats)), 'Number of mu_vecs and cov_mats must be equal.'
    
    g_vals = []
    for m,c in zip(mu_vecs, cov_mats): 
        g_vals.append(g(x_vec, mu_vec=m, cov_mat=c))
    
    max_index, max_value = max(enumerate(g_vals), key=operator.itemgetter(1))
    return (max_value, max_index + 1)

# %% [markdown]
# <a name="empirical_error"></a>
# ### Classifying data and calculating the empirical error

# %%
# Known parameters
cov_mat_1 = 4 * np.eye(2,2)
mu_vec_1 = np.array([[0],[0]])

cov_mat_2 = 4 * np.eye(2,2)
mu_vec_2 = np.array([[10],[0]])

cov_mat_3 = 5 * np.eye(2,2)
mu_vec_3 = np.array([[5],[5]])

# %% [markdown]
# <a name='emp_err_train'></a>
# ### Empirical error of the training dataset

# %%
# Empirical Error of the training set

import prettytable

class1_as_1 = 0
class1_as_2 = 0
class1_as_3 = 0
for row in train_set[train_set[:,2] == 1]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_vec_1, mu_vec_2, mu_vec_3],
        [cov_mat_1, cov_mat_2, cov_mat_3]
    )
    if g[1] == 2:
        class1_as_2 += 1
    elif g[1] == 3:
        class1_as_3 += 1
    else:
        class1_as_1 += 1

class2_as_1 = 0
class2_as_2 = 0
class2_as_3 = 0
for row in train_set[train_set[:,2] == 2]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_vec_1, mu_vec_2, mu_vec_3],
        [cov_mat_1, cov_mat_2, cov_mat_3]
    )
    if g[1] == 2:
        class2_as_2 += 1
    elif g[1] == 3:
        class2_as_3 += 1
    else:
        class2_as_1 += 1

class3_as_1 = 0
class3_as_2 = 0
class3_as_3 = 0
for row in train_set[train_set[:,2] == 3]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_vec_1, mu_vec_2, mu_vec_3],
        [cov_mat_1, cov_mat_2, cov_mat_3]
    )
    if g[1] == 2:
        class3_as_2 += 1
    elif g[1] == 3:
        class3_as_3 += 1
    else:
        class3_as_1 += 1

# %%
import prettytable

train_conf_mat = prettytable.PrettyTable(["test dataset", "w1 (predicted)", "w2 (predicted)", "w3 (predicted)"])
train_conf_mat.add_row(["w1 (actual)",class1_as_1, class1_as_2, class1_as_3])
train_conf_mat.add_row(["w2 (actual)",class2_as_1, class2_as_2, class2_as_3])
train_conf_mat.add_row(["w3 (actual)",class3_as_1, class3_as_2, class3_as_3])
print(train_conf_mat)
misclass = train_set.shape[0] - class1_as_1 - class2_as_2 - class3_as_3
print('Empirical Error: {:.2f} ({:.2f}%)'.format(misclass / train_set.shape[0], misclass / train_set.shape[0] * 100))
# Out:
# +--------------+----------------+----------------+----------------+
# | test dataset | w1 (predicted) | w2 (predicted) | w3 (predicted) |
# +--------------+----------------+----------------+----------------+
# | w1 (actual)  |      327       |       3        |       20       |
# | w2 (actual)  |       0        |      323       |       27       |
# | w3 (actual)  |       7        |       10       |      333       |
# +--------------+----------------+----------------+----------------+
# Empirical Error: 0.06 (6.38%)

# %% [markdown]
# <a name='emp_err_test'></a>
# ### Empirical error of the test dataset

# %%
# Empirical Error of the test dataset

import prettytable

class1_as_1 = 0
class1_as_2 = 0
class1_as_3 = 0
for row in test_set[test_set[:,2] == 1]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_vec_1, mu_vec_2, mu_vec_3],
        [cov_mat_1, cov_mat_2, cov_mat_3]
    )
    if g[1] == 2:
        class1_as_2 += 1
    elif g[1] == 3:
        class1_as_3 += 1
    else:
        class1_as_1 += 1

class2_as_1 = 0
class2_as_2 = 0
class2_as_3 = 0
for row in test_set[test_set[:,2] == 2]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_vec_1, mu_vec_2, mu_vec_3],
        [cov_mat_1, cov_mat_2, cov_mat_3]
    )
    if g[1] == 2:
        class2_as_2 += 1
    elif g[1] == 3:
        class2_as_3 += 1
    else:
        class2_as_1 += 1

class3_as_1 = 0
class3_as_2 = 0
class3_as_3 = 0
for row in test_set[test_set[:,2] == 3]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_vec_1, mu_vec_2, mu_vec_3],
        [cov_mat_1, cov_mat_2, cov_mat_3]
    )
    if g[1] == 2:
        class3_as_2 += 1
    elif g[1] == 3:
        class3_as_3 += 1
    else:
        class3_as_1 += 1

# %%
import prettytable

test_conf_mat = prettytable.PrettyTable(["test dataset", "w1 (predicted)", "w2 (predicted)", "w3 (predicted)"])
test_conf_mat.add_row(["w1 (actual)",class1_as_1, class1_as_2, class1_as_3])
test_conf_mat.add_row(["w2 (actual)",class2_as_1, class2_as_2, class2_as_3])
test_conf_mat.add_row(["w3 (actual)",class3_as_1, class3_as_2, class3_as_3])
print(test_conf_mat)
misclass = test_set.shape[0] - class1_as_1 - class2_as_2 - class3_as_3
print('Empirical Error: {:.2f} ({:.2f}%)'.format(misclass / test_set.shape[0], misclass / test_set.shape[0] * 100))
# Out:
# +--------------+----------------+----------------+----------------+
# | test dataset | w1 (predicted) | w2 (predicted) | w3 (predicted) |
# +--------------+----------------+----------------+----------------+
# | w1 (actual)  |      136       |       2        |       12       |
# | w2 (actual)  |       1        |      136       |       13       |
# | w3 (actual)  |       2        |       6        |      142       |
# +--------------+----------------+----------------+----------------+
# Empirical Error: 0.08 (8.00%)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <a name='task_1b'></a>
# # 1b)
# <a name="descr_task_1b"></a>
# Suppose $p([x_1,x_2]^t\;|\;\omega_i) \;∼ \; N(\pmb \mu_i,\pmb \Sigma_i), \; i = 1,2,3$, where the $\pmb \mu_i$’s and $\pmb \Sigma_i$’s are unknown. Use the training set to compute the MLE of the μi’s and the $\pmb \Sigma_i$’s. What is the error rate on the test set when the Bayes decision rule using the estimated parameters is employed for classification?
# <hr>

# %% [markdown]
# <a name='about_mle'></a>
# ## About the Maximum Likelihood Estimate (MLE)
#
# In contrast to task one, now we only know the number of parameters for the class conditional densities $p (\; \pmb x \; | \; \omega_i)$ and we want to use a Maximum Likelihood Estimatation (MLE) to estimate the quantities of these parameters from the training data.
#
#
# Given the information about the form of the model - the data is normal distributed - the 2 parameters to be estimated are $\pmb \mu_i$ and $\pmb \Sigma_i$, which are summarized by the
# parameter vector $\pmb \theta_i = \bigg[ \begin{array}{c}
# \ \theta_{i1} \\
# \ \theta_{i2} \\
# \end{array} \bigg]=
# \bigg[ \begin{array}{c}
# \pmb \mu_i \\
# \pmb \Sigma_i \\
# \end{array} \bigg]$

# %% [markdown]
# For the Maximum Likelihood Estimate (MLE), we assume that we have a set of samles $D = \left\{ \pmb x_1, \pmb x_2,..., \pmb x_n \right\} $ that are *i.i.d.* (independent and identically distributed, drawn with probability $p(\pmb x \; | \; \omega_i, \; \pmb \theta_i) $).
# Thus, we can **work with each class separately** and omit the class labels, so that we write the probability density as $p(\pmb x \; | \; \pmb \theta)$

# %% [markdown]
# <br>
# <br>
# ##### Likelihood of $ \pmb \theta $

# %% [markdown]
# Thus, the probability of observing $D = \left\{ \pmb x_1, \pmb x_2,..., \pmb x_n \right\} $ is:
# <br>
# <br>
# $p(D\; | \;  \pmb \theta\;) = p(\pmb x_1 \; | \; \pmb \theta\;)\; \cdot \; p(\pmb x_2 \; | \;\pmb \theta\;) \; \cdot \;...  \; p(\pmb x_n \; | \; \pmb \theta\;) = \prod_{k=1}^{n} \; p(\pmb x_k \pmb \; | \; \pmb \theta \;)$
# <br>
# Where $p(D\; | \;  \pmb  \theta\;)$ is also called the ***likelihood of $\pmb\ \theta$***.

# %% [markdown]
# We are given the information that $p([x_1,x_2]^t) \;∼ \; N(\pmb \mu,\pmb \Sigma) $ (remember that we dropped the class labels, since we are working with every class separately).

# %% [markdown]
# And the mutlivariate normal density is given as:
# $\quad \quad p(\pmb x) = \frac{1}{(2\pi)^{d/2} \; |\Sigma|^{1/2}} exp \bigg[ -\frac{1}{2}(\pmb x - \pmb \mu)^t \Sigma^{-1}(\pmb x - \pmb \mu) \bigg]$
#
# So that
# $p(D\; | \;  \pmb \theta\;) = \prod_{k=1}^{n} \; p(\pmb x_k \pmb \; | \; \pmb \theta \;) =  \prod_{k=1}^{n} \; \frac{1}{(2\pi)^{d/2} \; |\Sigma|^{1/2}} exp \bigg[ -\frac{1}{2}(\pmb x - \pmb \mu)^t \Sigma^{-1}(\pmb x - \pmb \mu) \bigg]$

# %% [markdown]
# Since it is easier to work with the logarithm, we define the log-likelihood function $l(\pmb \theta)$ as
# $l(\pmb \theta) \equiv ln\; p(D\; | \;  \pmb \theta\;) = \sum\limits_{k=1}^{n} \;ln\; p(\pmb x_k \pmb \; | \; \pmb \theta \;)$

# %% [markdown]
# and the log of the multivariate density

# %% [markdown]
# $ l(\pmb\theta) =  \sum\limits_{k=1}^{n} - \frac{1}{2}(\pmb x - \pmb \mu)^t \pmb \Sigma^{-1} \; (\pmb x - \pmb \mu) - \frac{d}{2} \; ln \; 2\pi - \frac{1}{2} \;ln \; |\pmb\Sigma|$

# %% [markdown]
# <br>
# <br>
# #### Maximum Likelihood Estimate (MLE)

# %% [markdown]
# In order to obtain the MLE $\boldsymbol{\hat{\theta}}$, we maximize $l (\pmb  \theta)$, which can be done via differentiation:
#
# with
# $\nabla_{\pmb \theta} \equiv \begin{bmatrix}
# \frac{\partial \; }{\partial \; \theta_1} \\
# \frac{\partial \; }{\partial \; \theta_2}
# \end{bmatrix} = \begin{bmatrix}
# \frac{\partial \; }{\partial \; \pmb \mu} \\
# \frac{\partial \; }{\partial \; \pmb \sigma}
# \end{bmatrix}$

# %% [markdown]
# $\nabla_{\pmb \theta} l = \sum\limits_{k=1}^n \nabla_{\pmb \theta} \;ln\; p(\pmb x| \pmb \theta) = 0 $

# %% [markdown]
# <a name='mle_mu'></a>
# ## MLE of the mean vector $\pmb \mu$

# %% [markdown]
# The MLE of the parameter $\pmb\mu$ is given by the equation:
# ${\hat{\pmb\mu}} = \frac{1}{n} \sum\limits_{k=1}^{n} \pmb x_k$

# %%
import prettytable

mu_est_1 = np.sum(train_set[train_set[:,2] == 1], axis=0)/len(train_set[train_set[:,2] == 1])
mu_est_1 = mu_est_1[0:2].reshape(2,1)
mu_est_2 = np.sum(train_set[train_set[:,2] == 2], axis=0)/len(train_set[train_set[:,2] == 2])
mu_est_2 = mu_est_2[0:2].reshape(2,1)
mu_est_3 = np.sum(train_set[train_set[:,2] == 3], axis=0)/len(train_set[train_set[:,2] == 3])
mu_est_3 = mu_est_3[0:2].reshape(2,1)

print(mu_est_1)
mu_mle = prettytable.PrettyTable(["", "mu_1", "mu_2", "mu_3"])
mu_mle.add_row(["MLE",mu_est_1, mu_est_2, mu_est_3])
mu_mle.add_row(["actual",mu_vec_1, mu_vec_2, mu_vec_3])

print(mu_mle)
# Out:
# [ 0.19298829 -0.04618914  1.        ]
# [[ 0.19298829]
#  [-0.04618914]]
# +--------+-----------------+-----------------+-----------------+
# |        |       mu_1      |       mu_2      |       mu_3      |
# +--------+-----------------+-----------------+-----------------+
# |  MLE   |  [[ 0.19298829] |  [[ 9.916212  ] |  [[ 5.06426086] |
# |        |  [-0.04618914]] |  [ 0.05908629]] |  [ 4.88450171]] |
# | actual |       [[0]      |      [[10]      |       [[5]      |
# |        |       [0]]      |       [ 0]]     |       [5]]      |
# +--------+-----------------+-----------------+-----------------+

# %% [markdown]
# <a name='mle_sigma'></a>
# ## MLE of the covariance matrix $\pmb \Sigma$
#
# The MLE of the parameter $\pmb\Sigma$ is given by the equation:

# %% [markdown]
# ${\hat{\pmb\Sigma}} = \frac{1}{n} \sum\limits_{k=1}^{n} (\pmb x_k - \hat{\mu})(\pmb x_k - \hat{\mu})^t$

# %%
import prettytable

def mle_est_cov(x_samples, mu_est):
    """
    Calculates the Maximum Likelihood Estimate for the covariance matrix.
    
    Keyword Arguments:
        x_samples: np.array of the samples for 1 class, n x d dimensional 
        mu_est: np.array of the mean MLE, d x 1 dimensional
        
    Returns the MLE for the covariance matrix as d x d numpy array.
    
    """
    cov_est = np.zeros((2,2))
    for x_vec in x_samples:
        x_vec = x_vec.reshape(2,1)
        assert(x_vec.shape == mu_est.shape), 'mean and x vector hmust be of equal shape'
        cov_est += (x_vec - mu_est).dot((x_vec - mu_est).T)
    return cov_est / len(x_samples)


class1_train_samples1 = train_set[train_set[:,2] == 1][:,0:2]
cov_est_1 = mle_est_cov(class1_train_samples1, mu_est_1)

class1_train_samples2 = train_set[train_set[:,2] == 2][:,0:2]
cov_est_2 = mle_est_cov(class1_train_samples2, mu_est_2)

class1_train_samples3 = train_set[train_set[:,2] == 3][:,0:2]
cov_est_3 = mle_est_cov(class1_train_samples3, mu_est_3)




cov_mle = prettytable.PrettyTable(["", "covariance_matrix_1", "covariance_matrix_2", "covariance_matrix_3"])
cov_mle.add_row(["MLE", cov_est_1, cov_est_2, cov_est_3])
cov_mle.add_row(['','','',''])
cov_mle.add_row(["actual", cov_mat_1, cov_mat_2, cov_mat_3])

print(cov_mle)
# Out:
# +--------+-----------------------------+-----------------------------+-----------------------------+
# |        |     covariance_matrix_1     |     covariance_matrix_2     |     covariance_matrix_3     |
# +--------+-----------------------------+-----------------------------+-----------------------------+
# |  MLE   |  [[ 4.99133045 -0.09737531] |  [[ 5.64913253  0.01850218] |  [[ 3.94634287 -0.12715664] |
# |        |  [-0.09737531  4.52491813]] |  [ 0.01850218  4.79555152]] |  [-0.12715664  4.22477661]] |
# |        |                             |                             |                             |
# | actual |          [[ 4.  0.]         |          [[ 4.  0.]         |          [[ 5.  0.]         |
# |        |          [ 0.  4.]]         |          [ 0.  4.]]         |          [ 0.  5.]]         |
# +--------+-----------------------------+-----------------------------+-----------------------------+

# %% [markdown]
# <a name='error_mle'></a>
# ## Error on the test set using the estimated parameters
#
# Using the estimated parameters $\pmb \mu_i$ and $\pmb \Sigma_i$, which we obtained via MLE, we calculate the error on the test data set again.

# %%
# Empirical Error of the test dataset
import prettytable

class1_as_1 = 0
class1_as_2 = 0
class1_as_3 = 0
for row in test_set[test_set[:,2] == 1]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_est_1, mu_est_2, mu_est_3],
        [cov_est_1, cov_est_2, cov_est_3]
    )
    if g[1] == 2:
        class1_as_2 += 1
    elif g[1] == 3:
        class1_as_3 += 1
    else:
        class1_as_1 += 1

class2_as_1 = 0
class2_as_2 = 0
class2_as_3 = 0
for row in test_set[test_set[:,2] == 2]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_est_1, mu_est_2, mu_est_3],
        [cov_est_1, cov_est_2, cov_est_3]
    )
    if g[1] == 2:
        class2_as_2 += 1
    elif g[1] == 3:
        class2_as_3 += 1
    else:
        class2_as_1 += 1

class3_as_1 = 0
class3_as_2 = 0
class3_as_3 = 0
for row in test_set[test_set[:,2] == 3]:
    g = classify_data(
        row[0:2], 
        discriminant_function,
        [mu_est_1, mu_est_2, mu_est_3],
        [cov_est_1, cov_est_2, cov_est_3]
    )
    if g[1] == 2:
        class3_as_2 += 1
    elif g[1] == 3:
        class3_as_3 += 1
    else:
        class3_as_1 += 1     
        
test_conf_mat = prettytable.PrettyTable(["test dataset", "w1 (predicted)", "w2 (predicted)", "w3 (predicted)"])
test_conf_mat.add_row(["w1 (actual)",class1_as_1, class1_as_2, class1_as_3])
test_conf_mat.add_row(["w2 (actual)",class2_as_1, class2_as_2, class2_as_3])
test_conf_mat.add_row(["w3 (actual)",class3_as_1, class3_as_2, class3_as_3])
print(test_conf_mat)
misclass = test_set.shape[0] - class1_as_1 - class2_as_2 - class3_as_3
print('Empirical Error: {:.2f} ({:.2f}%)'.format(misclass / test_set.shape[0], misclass / test_set.shape[0] * 100))
# Out:
# +--------------+----------------+----------------+----------------+
# | test dataset | w1 (predicted) | w2 (predicted) | w3 (predicted) |
# +--------------+----------------+----------------+----------------+
# | w1 (actual)  |      141       |       0        |       9        |
# | w2 (actual)  |       0        |      145       |       5        |
# | w3 (actual)  |       10       |       3        |      137       |
# +--------------+----------------+----------------+----------------+
# Empirical Error: 0.06 (6.00%)

# %% [markdown]
# As we can see from the results, the empirical error on the test training set decreased from 8.00% to 6.00%.

# %% [markdown]
# <br>
# <br>
# <a name='task_1c'></a>
# # 1 c)
#
# <a name='description_1c'></a>
# Suppose the form of the distributions of $p([x_1, x_2]^t\;|\;\omega_i),\; i = 1,2,3$ is unknown. Assume that the training dataset can be used to estimate the density at a point using the Parzen window technique (a spherical Gaussian kernel with h = 1). What is the error rate on the test set when the Bayes decision rule is employed for classification?
# <hr>

# %% [markdown]
# Starting with a simple example to count the number $k_n$, the equation using a hypercube would be  $k_n = \sum\limits_{i=1}^{n} \phi \bigg( \frac{\pmb x - \pmb x_i}{h_n} \bigg)$
#
# where $\phi(\pmb u)$ is the window function, and here: $\pmb u = \bigg( \frac{\pmb x - \pmb x_i}{h_n} \bigg)$

# %% [markdown]
# Based on this window, we can now formulate the Parzen-window estimation with a hypercube kernel as follows:
#
# $P_n(\pmb x) = \frac{1}{n} \sum\limits_{i=1}^{n} \frac{1}{h^d} \phi \bigg[ \frac{\pmb x - \pmb x_i}{h_n} \bigg]$
#
# where
# $h^d = V_n\quad$   and    $\quad\phi \bigg[ \frac{\pmb x - \pmb x_i}{h_n} \bigg] = k$

# %% [markdown]
# For the Gaussian kernel (instead of the hypercube), we can just simply swap the terms of the window function by:
#
# $\frac{1}{(\sqrt {2 \pi})^d h_{n}^{d}} exp \; \bigg[ -\frac{1}{2} \bigg(\frac{\pmb x - \pmb x_i}{h_n} \bigg)^2 \bigg]$

# %% [markdown]
# So that we have the Parzen window estimation becomes:
#
# $P_n(\pmb x) = \frac{1}{n} \sum\limits_{i=1}^{n} \frac{1}{h^d} \phi \Bigg[ \frac{1}{(\sqrt {2 \pi})^d h_{n}^{d}} exp \; \bigg[ -\frac{1}{2} \bigg(\frac{\pmb x - \pmb x_i}{h_n} \bigg)^2 \bigg] \Bigg]$

# %% [markdown]
# <br>
# <br>
# <a name="use_parzen"></a>
# ## Using the Parzen-window technique for Gaussian kernel desnity estimation

# %%
from scipy.stats import kde
class1_kde = kde.gaussian_kde(train_set[train_set[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde = kde.gaussian_kde(train_set[train_set[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde = kde.gaussian_kde(train_set[train_set[:,2] == 3].T[0:2], bw_method=1.0)

# %%
# %pylab inline
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.mlab import bivariate_normal
from mpl_toolkits.mplot3d import Axes3D

X = np.linspace(-10, 20, 100)
Y = np.linspace(-10, 20, 100)
X,Y = np.meshgrid(X,Y)

for bwmethod,title in zip([class1_kde, class2_kde, class3_kde], ['class1', 'class2', 'class3']):
    fig = plt.figure(figsize=(10, 7))
    ax = fig.gca(projection='3d')
    Z = bwmethod(np.array([X.ravel(),Y.ravel()]))
    Z = Z.reshape(100,100)
    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm,
        linewidth=0, antialiased=False)

    ax.set_zlim(0, 0.02)
    ax.zaxis.set_major_locator(plt.LinearLocator(10))
    ax.zaxis.set_major_formatter(plt.FormatStrFormatter('%.02f'))
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('p(x)')
    
    plt.title('Gaussian kernel, bw_method %s' %title)
    fig.colorbar(surf, shrink=0.5, aspect=7, cmap=plt.cm.coolwarm)
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['title']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <br>
# <br>
# <a name='bayes_rule_parzen'></a>
# ###Implementing the classifier using  Bayes' decision rule
#
#
# $decide \; \omega_j \; for \;\; max \;\bigg[ P(\omega_j|x) = \frac{p(x|\omega_j) * P(\omega_j)}{p(x)} \bigg]\;, \;\; j = 1, 2, 3 $
#
# We can remove the prior probabilities (equal priors) and the scale factor:
#
#
# $decide \; \omega_j \; for \;\; max \;[ p(x|\omega_j) ]\;, \;\; j = 1, 2, 3 $

# %%
import operator

def bayes_classifier(x_vec, kdes):
    """
    Classifies an input sample into 1 out of 3 classes determined by
    maximizing the class conditional probability p(x|w_j).
    
    Keyword arguments:
        x_vec: A dx1 dimensional numpy array representing the sample.
        kdes: List of the gausssian_kde (kernel density) estimates
      
    Returns a tuple ( (x|w_j)_value, class label ).
    
    """
    p_vals = []
    for kde in kdes:
        p_vals.append(kde.evaluate(x_vec))
    max_index, max_value = max(enumerate(p_vals), key=operator.itemgetter(1))
    return (max_value, max_index + 1)

# %% [markdown]
# <a name='error_parzen'></a>
# ## Error on the test set using the likelihoods from the Gaussian kernel estimate of the Parzen-window technique

# %%
# Empirical Error of the test dataset
import prettytable

class1_as_1 = 0
class1_as_2 = 0
class1_as_3 = 0
for row in test_set[test_set[:,2] == 1]:
    g = bayes_classifier(row[0:2], [class1_kde, class2_kde, class3_kde])
    if g[1] == 2:
        class1_as_2 += 1
    elif g[1] == 3:
        class1_as_3 += 1
    else:
        class1_as_1 += 1

class2_as_1 = 0
class2_as_2 = 0
class2_as_3 = 0
for row in test_set[test_set[:,2] == 2]:
    g = bayes_classifier(row[0:2], [class1_kde, class2_kde, class3_kde])
    if g[1] == 2:
        class2_as_2 += 1
    elif g[1] == 3:
        class2_as_3 += 1
    else:
        class2_as_1 += 1

class3_as_1 = 0
class3_as_2 = 0
class3_as_3 = 0
for row in test_set[test_set[:,2] == 3]:
    g = bayes_classifier(row[0:2], [class1_kde, class2_kde, class3_kde])
    if g[1] == 2:
        class3_as_2 += 1
    elif g[1] == 3:
        class3_as_3 += 1
    else:
        class3_as_1 += 1     
        
test_conf_mat = prettytable.PrettyTable(["test dataset", "w1 (predicted)", "w2 (predicted)", "w3 (predicted)"])
test_conf_mat.add_row(["w1 (actual)",class1_as_1, class1_as_2, class1_as_3])
test_conf_mat.add_row(["w2 (actual)",class2_as_1, class2_as_2, class2_as_3])
test_conf_mat.add_row(["w3 (actual)",class3_as_1, class3_as_2, class3_as_3])
print(test_conf_mat)
misclass = test_set.shape[0] - class1_as_1 - class2_as_2 - class3_as_3
print('Empirical Error: {:.2f} ({:.2f}%)'.format(misclass / test_set.shape[0], misclass / test_set.shape[0] * 100))
# Out:
# +--------------+----------------+----------------+----------------+
# | test dataset | w1 (predicted) | w2 (predicted) | w3 (predicted) |
# +--------------+----------------+----------------+----------------+
# | w1 (actual)  |      142       |       0        |       8        |
# | w2 (actual)  |       1        |      144       |       5        |
# | w3 (actual)  |       3        |       3        |      144       |
# +--------------+----------------+----------------+----------------+
# Empirical Error: 0.04 (4.44%)

# %% [markdown]
# <br>
# <br>
# <a name='task_1e'></a>
# # 1e)

# %% [markdown]
# <a name='description_1e'></a>
# Repeat the above three classification procedures by varying the size of the training set as follows: 10%, 20%, 30%, 40%, 50%, 60%, 70%, 80%, 90% of each class. Plot the error rate as a function of the size of the training set for each of the 3 cases.

# %% [markdown]
# <br>
# <br>
# <a name='shrink_train'></a>
# ## Creating training sets with variable size

# %%
# This workaround is necessary to make sure that every subset contains same number of
# samples for each of the three classes

train_subsets_c1 = {}
for p in reversed([i/10 for i in range(1,11)]):
    t = train_set[train_set[:,2] == 1]
    train_subsets_c1[int(p*100)] = t[np.random.choice(t.shape[0], t.shape[0] * p, replace=False),:]
    
train_subsets_c2 = {}
for p in reversed([i/10 for i in range(1,11)]):
    t = train_set[train_set[:,2] == 2]
    train_subsets_c2[int(p*100)] = t[np.random.choice(t.shape[0], t.shape[0] * p, replace=False),:]
    
train_subsets_c3 = {}
for p in reversed([i/10 for i in range(1,11)]):
    t = train_set[train_set[:,2] == 3]
    train_subsets_c3[int(p*100)] = t[np.random.choice(t.shape[0], t.shape[0] * p, replace=False),:]

# combine separate-class subsets for convenience
train_subsets = {}
for set_size in sorted(train_subsets_c1.keys()):
    t_set = np.zeros(shape=(1,3))
    for subset in [train_subsets_c1, train_subsets_c2, train_subsets_c3]:        
        t_set = np.append(t_set, subset[set_size], axis=0)
        # delete the first placeholder row used for initializing the array                                  
    t_set = np.delete(t_set, 0, axis=0)
    train_subsets[set_size] = t_set

for i in sorted(train_subsets):
    print(i, train_subsets[i].shape)
# Out:
# 10 (105, 3)
# 20 (210, 3)
# 30 (315, 3)
# 40 (420, 3)
# 50 (525, 3)
# 60 (630, 3)
# 70 (732, 3)
# 80 (840, 3)
# 90 (945, 3)
# 100 (1050, 3)

# %%
#Plotting one subset to confirm that the reduction worked error-free

f, ax = plt.subplots(figsize=(7, 7))
ax.scatter(train_subsets[30][train_subsets[30][:,2] == 1][:,0], train_subsets[30][train_subsets[30][:,2] == 1][:,1], \
           marker='o', color='green', s=40, alpha=0.5, label='$\omega_1$')
ax.scatter(train_subsets[30][train_subsets[30][:,2] == 2][:,0], train_subsets[30][train_subsets[30][:,2] == 2][:,1], \
           marker='^', color='red', s=40, alpha=0.5, label='$\omega_2$')
ax.scatter(train_subsets[30][train_subsets[30][:,2] == 3][:,0], train_subsets[30][train_subsets[30][:,2] == 3][:,1], \
           marker='s', color='blue', s=40, alpha=0.5, label='$\omega_3$')
plt.legend(loc='upper right') 
plt.title('Training datset after reducing the size to 30%', size=20)
plt.ylabel('$x_2$', size=20)
plt.xlabel('$x_1$', size=20)
plt.show()

# %% [markdown]
# <br>
# <br>
# <a name='mle_varying'></a>
# ## MLE error rate for varying training set sizes

# %% [markdown]
# The MLE of the parameter $\pmb\mu$ is given by the equation:
# ${\hat{\pmb\mu}} = \frac{1}{n} \sum\limits_{k=1}^{n} \pmb x_k$

# %%
mu_estimates = {}

for set_size in sorted(train_subsets):
    mu1_est = np.sum(train_subsets[set_size][train_subsets[set_size][:,2] == 1], axis=0)/\
        len(train_subsets[set_size][train_subsets[set_size][:,2] == 1])
    mu1_est = mu1_est[0:2].reshape(2,1)
    mu2_est = np.sum(train_subsets[set_size][train_subsets[set_size][:,2] == 2], axis=0)/\
        len(train_subsets[set_size][train_subsets[set_size][:,2] == 2])
    mu2_est = mu1_est[0:2].reshape(2,1)
    mu3_est = np.sum(train_subsets[set_size][train_subsets[set_size][:,2] == 3], axis=0)/\
        len(train_subsets[set_size][train_subsets[set_size][:,2] == 3])
    mu3_est = mu1_est[0:2].reshape(2,1)
    
    mu_estimates[set_size] = [mu1_est, mu2_est, mu3_est]

# %% [markdown]
# The MLE of the parameter $\pmb\Sigma$ is given by the equation:
# ${\hat{\pmb\Sigma}} = \frac{1}{n} \sum\limits_{k=1}^{n} (\pmb x_k - \hat{\mu})(\pmb x_k - \hat{\mu})^t$

# %%
def mle_est_cov(x_samples, mu_est):
    """
    Calculates the Maximum Likelihood Estimate for the covariance matrix.
    
    Keyword Arguments:
        x_samples: np.array of the samples for 1 class, n x d dimensional 
        mu_est: np.array of the mean MLE, d x 1 dimensional
        
    Returns the MLE for the covariance matrix as d x d numpy array.
    
    """
    cov_est = np.zeros((2,2))
    for x_vec in x_samples:
        x_vec = x_vec.reshape(2,1)
        assert(x_vec.shape == mu_est.shape), 'mean and x vector hmust be of equal shape'
        cov_est += (x_vec - mu_est).dot((x_vec - mu_est).T)
    return cov_est / len(x_samples)


cov_estimates = {}

for set_size in sorted(train_subsets):

    class1_train_samples = train_subsets[set_size][train_subsets[set_size][:,2] == 1][:,0:2]
    cov1_est = mle_est_cov(class1_train_samples, mu_estimates[set_size][0])
    
    class2_train_samples = train_subsets[set_size][train_subsets[set_size][:,2] == 2][:,0:2]
    cov2_est = mle_est_cov(class2_train_samples, mu_estimates[set_size][0])
    
    class3_train_samples = train_subsets[set_size][train_subsets[set_size][:,2] == 3][:,0:2]
    cov3_est = mle_est_cov(class3_train_samples, mu_estimates[set_size][0])
    
    cov_estimates[set_size] = [cov1_est, cov2_est, cov3_est]

# %%
# Empirical Error of the test dataset
import prettytable

emp_errors_kde = []
for kdes in [[class1_kde100, class2_kde100, class2_kde100],
          [class1_kde90, class2_kde90, class2_kde90],
          [class1_kde80, class2_kde80, class2_kde80],
          [class1_kde70, class2_kde70, class2_kde70],
          [class1_kde60, class2_kde60, class2_kde60],
          [class1_kde50, class2_kde50, class2_kde50],
          [class1_kde40, class2_kde40, class2_kde40],
          [class1_kde30, class2_kde30, class2_kde30],
          [class1_kde20, class2_kde20, class2_kde20],
          [class1_kde10, class2_kde10, class2_kde10]]:
    class1_as_1 = 0
    class1_as_2 = 0
    class1_as_3 = 0
    for row in test_set[test_set[:,2] == 1]:
        g = bayes_classifier(row[0:2], kdes)
        if g[1] == 2:
            class1_as_2 += 1
        elif g[1] == 3:
            class1_as_3 += 1
        else:
            class1_as_1 += 1

    class2_as_1 = 0
    class2_as_2 = 0
    class2_as_3 = 0
    for row in test_set[test_set[:,2] == 2]:
        g = bayes_classifier(row[0:2], kdes)
        if g[1] == 2:
            class2_as_2 += 1
        elif g[1] == 3:
            class2_as_3 += 1
        else:
            class2_as_1 += 1

    class3_as_1 = 0
    class3_as_2 = 0
    class3_as_3 = 0
    for row in test_set[test_set[:,2] == 3]:
        g = bayes_classifier(row[0:2], kdes)
        if g[1] == 2:
            class3_as_2 += 1
        elif g[1] == 3:
            class3_as_3 += 1
        else:
            class3_as_1 += 1     
        
    misclass = test_set.shape[0] - class1_as_1 - class2_as_2 - class3_as_3
    emp_error = misclass / test_set.shape[0]
    emp_errors_kde.append(emp_error)

# %% [markdown]
# <br>
# <br>
# <a name='parzen_varying'></a>
# ## Error rate of kernel density estimaton via Parzen-window for varying training sizes

# %%
from scipy.stats import kde
class1_kde100 = kde.gaussian_kde(train_set[train_set[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde100 = kde.gaussian_kde(train_set[train_set[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde100 = kde.gaussian_kde(train_set[train_set[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde90 = kde.gaussian_kde(train_90perc[train_90perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde90 = kde.gaussian_kde(train_90perc[train_90perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde90 = kde.gaussian_kde(train_90perc[train_90perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde80 = kde.gaussian_kde(train_80perc[train_80perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde80 = kde.gaussian_kde(train_80perc[train_80perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde80 = kde.gaussian_kde(train_80perc[train_80perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde70 = kde.gaussian_kde(train_70perc[train_70perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde70 = kde.gaussian_kde(train_70perc[train_70perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde70 = kde.gaussian_kde(train_70perc[train_70perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde60 = kde.gaussian_kde(train_60perc[train_60perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde60 = kde.gaussian_kde(train_60perc[train_60perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde60 = kde.gaussian_kde(train_60perc[train_60perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde50 = kde.gaussian_kde(train_50perc[train_50perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde50 = kde.gaussian_kde(train_50perc[train_50perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde50 = kde.gaussian_kde(train_50perc[train_50perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde40 = kde.gaussian_kde(train_40perc[train_40perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde40 = kde.gaussian_kde(train_40perc[train_40perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde40 = kde.gaussian_kde(train_40perc[train_40perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde30 = kde.gaussian_kde(train_30perc[train_30perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde30 = kde.gaussian_kde(train_30perc[train_30perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde30 = kde.gaussian_kde(train_30perc[train_30perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde20 = kde.gaussian_kde(train_20perc[train_20perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde20 = kde.gaussian_kde(train_20perc[train_20perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde20 = kde.gaussian_kde(train_20perc[train_20perc[:,2] == 3].T[0:2], bw_method=1.0)

class1_kde10 = kde.gaussian_kde(train_10perc[train_20perc[:,2] == 1].T[0:2], bw_method=1.0)
class2_kde10 = kde.gaussian_kde(train_10perc[train_20perc[:,2] == 2].T[0:2], bw_method=1.0)
class3_kde10 = kde.gaussian_kde(train_10perc[train_20perc[:,2] == 3].T[0:2], bw_method=1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-3254e9b0a8c6> in <module>()
#       4 class3_kde100 = kde.gaussian_kde(train_set[train_set[:,2] == 3].T[0:2], bw_method=1.0)
#       5
# ----> 6 class1_kde90 = kde.gaussian_kde(train_90perc[train_90perc[:,2] == 1].T[0:2], bw_method=1.0)
#       7 class2_kde90 = kde.gaussian_kde(train_90perc[train_90perc[:,2] == 2].T[0:2], bw_method=1.0)
#       8 class3_kde90 = kde.gaussian_kde(train_90perc[train_90perc[:,2] == 3].T[0:2], bw_method=1.0)
#
# TypeError: 'int' object is not subscriptable

# %%
# Empirical Error of the test dataset
import prettytable

emp_errors_kde = []
for kdes in [[class1_kde100, class2_kde100, class2_kde100],
          [class1_kde90, class2_kde90, class2_kde90],
          [class1_kde80, class2_kde80, class2_kde80],
          [class1_kde70, class2_kde70, class2_kde70],
          [class1_kde60, class2_kde60, class2_kde60],
          [class1_kde50, class2_kde50, class2_kde50],
          [class1_kde40, class2_kde40, class2_kde40],
          [class1_kde30, class2_kde30, class2_kde30],
          [class1_kde20, class2_kde20, class2_kde20],
          [class1_kde10, class2_kde10, class2_kde10]]:
    class1_as_1 = 0
    class1_as_2 = 0
    class1_as_3 = 0
    for row in test_set[test_set[:,2] == 1]:
        g = bayes_classifier(row[0:2], kdes)
        if g[1] == 2:
            class1_as_2 += 1
        elif g[1] == 3:
            class1_as_3 += 1
        else:
            class1_as_1 += 1

    class2_as_1 = 0
    class2_as_2 = 0
    class2_as_3 = 0
    for row in test_set[test_set[:,2] == 2]:
        g = bayes_classifier(row[0:2], kdes)
        if g[1] == 2:
            class2_as_2 += 1
        elif g[1] == 3:
            class2_as_3 += 1
        else:
            class2_as_1 += 1

    class3_as_1 = 0
    class3_as_2 = 0
    class3_as_3 = 0
    for row in test_set[test_set[:,2] == 3]:
        g = bayes_classifier(row[0:2], kdes)
        if g[1] == 2:
            class3_as_2 += 1
        elif g[1] == 3:
            class3_as_3 += 1
        else:
            class3_as_1 += 1     
        
    misclass = test_set.shape[0] - class1_as_1 - class2_as_2 - class3_as_3
    emp_error = misclass / test_set.shape[0]
    emp_errors_kde.append(emp_error)

# %% [markdown]
# <br>
# <br>
# <a name='k_nearest_error'></a>
#
# ##Error rate of the k-nearest-neighbor technique for varying training sizes

# %% [markdown]
# <a name='plot_error_func'></a>
# ## Plotting the error rate as a function of the size of the training set for each of the 3 cases

# %%
import matplotlib.pyplot as plt

tr_set_sizes = [train_set.shape[0] * p for p in reversed([i/10 for i in range(1,11)])]

plt.plot(tr_set_sizes, emp_errors_kde, '-x')
plt.xlabel('training set size')
plt.ylabel('Error rate on test data set')
plt.title('Error rate for different training set sizes')
plt.show()

# %%
import copy

train_set_copy = copy.deepcopy(train_set)
subset = {}
for percent in np.arange(10, 100, 10):
    np.random.shuffle(train_set_copy) # shuffle in-place
    subset[percent] = train_set_copy[:len(train_set_copy)*percent*0.01] # selection of training data

# %%
for i in subset:
    print(subset[i].shape)
# Out:
# (840, 3)
# (525, 3)
# (210, 3)
# (735, 3)
# (420, 3)
# (105, 3)
# (630, 3)
# (945, 3)
# (315, 3)

# %%
train_subsets = {}
for p in reversed([i/10 for i in range(1,11)]):
    train_subsets[p] = train_set[np.random.choice(train_set.shape[0],\
    train_set.shape[0] * size, replace=False),:]

# %%
for i in subset:
    print(subset[i].shape)
# Out:
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)
# (105, 3)

# %%
mu1_est_100 = sum(train_set[train_set[:,2] == 1])/len(train_set[train_set[:,2] == 1])
mu1_est_100 = mu1_est_100[0:2].reshape(2,1)
print(mu1_est_100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-121e271fb35e> in <module>()
#       1 mu1_est_100 = sum(train_set[train_set[:,2] == 1])/len(train_set[train_set[:,2] == 1])
# ----> 2 mu1_est_100 = mu1_est_100[0:2].reshape(2,1)
#       3 print(mu1_est_100)
#
# IndexError: invalid index to scalar variable.
