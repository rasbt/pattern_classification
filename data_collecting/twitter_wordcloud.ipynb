# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -d
# Out:
# Sebastian Raschka 20/12/2014
#
# CPython 3.4.2
# IPython 2.3.1

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Turn Your Twitter Timeline into a Word Cloud Using Python

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Sections

# %% [markdown]
# - [Requirements](#Requirements)
# - [A. Downloading Your Twitter Timeline Tweets](#A.-Downloading-Your-Twitter-Timeline-Tweets)
# - [B. Creating the Word Cloud](#A.-Downloading-Your-Twitter-Timeline-Tweets)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Requirements

# %% [markdown]
# [[back to top](#Sections)]

# %% [markdown]
# Before we get started, I want to list some of the required packages to make this work!

# %% [markdown]
# Below, you find a list of the basic packages which can be installed via
#
#     pip install <package_name>
#
# - [twitter](https://pypi.python.org/pypi/twitter)
# - [pyprind](https://pypi.python.org/pypi/PyPrind/)
# - [numpy](http://numpy.org)
# - [matplotlib](http://matplotlib.org)
# - [pandas](http://pandas.pydata.org)
# - [scipy](http://www.scipy.org)
#
#
#
#
# And the Python (2.7) [`wordcloud`](https://github.com/amueller/word_cloud) package by Andreas Mueller can be installed via
#
#     pip install git+git://github.com/amueller/word_cloud.git
#
# Note that `wordcloud` requires Python's imaging library [PIL](http://effbot.org/imagingbook/pil-index.htm). Depending on the operating system, the installation and setup of PIL can be quite challenging; however, when I tried to install it on different MacOS and Linux systems via [`conda`](http://www.continuum.io/blog/conda) it always seemed to work seamlessly:
#
#     conda install pil

# %% [markdown]
# Let me use my handy [`watermark`](https://github.com/rasbt/watermark) extension to summarize the different packages and version numbers that were used in my case to download the twitter timeline and create the word cloud:

# %%
# %load_ext watermark
# %watermark -d -v -m -p twitter,pyprind,wordcloud,pandas,scipy,matplotlib
# Out:
# 28/11/2014
#
# CPython 2.7.8
# IPython 2.1.0
#
# twitter 1.15.0
# pyprind 2.8.0
# wordcloud 1.0.0
# pandas 0.14.1
# scipy 0.14.0
# matplotlib 1.3.1
#
# compiler   : GCC 4.2.1 (Apple Inc. build 5577)
# system     : Darwin
# release    : 14.0.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 2
# interpreter: 64bit

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## A. Downloading Your Twitter Timeline Tweets

# %% [markdown]
# [[back to top](#Sections)]

# %% [markdown]
# In order to get access to the Twitter API through OAuth (open standard for authorization), we have to obtain our consumer information and access tokens first by registering our app on [https://apps.twitter.com](https://apps.twitter.com).

# %%
CONSUMER_KEY = 'enter your information here'
CONSUMER_SECRET = 'enter your information here'
ACCESS_TOKEN = 'enter your information here'
ACCESS_TOKEN_SECRET = 'enter your information here'
USER_NAME = 'enter your twitter handle here'

# %% [markdown]
# The following code can then be used to download your timeline "sequentially" in chunks of 200 tweets per request to overcome the twitter API limitation, which only allows you to download 200 tweets at a time.

# %%
# Sebastian Raschka, 2014
# Code for downloading your personal twitter timeline.

import twitter
from datetime import datetime
import time
import re
import sys
import pandas as pd
import pyprind as pp

class TimelineMiner(object):
    def __init__(self, access_token, access_secret, consumer_key, consumer_secret, user_name):
        self.access_token = access_token
        self.access_secret = access_secret
        self.consumer_key = consumer_key
        self.consumer_secret = consumer_secret
        self.user_name = user_name
        self.auth = None
        self.df = pd.DataFrame(columns=['timestamp', 'tweet'], dtype='str')


    def authenticate(self):
        self.auth = twitter.Twitter(auth=twitter.OAuth(self.access_token, 
                    self.access_secret, self.consumer_key, 
                    self.consumer_secret))
        return bool(isinstance(self.auth, twitter.api.Twitter))
        

    def get_timeline(self, max=0, keywords=[]):
        if keywords:
            self.df['keywords'] = ''
        tweet_ids = [self.auth.statuses.user_timeline(
                user_id=self.user_name, count=1
                )[0]['id']] # the ID of my last tweet
        last_count = 200
        counter = 0
        while last_count == 200:
            timeline = self.auth.statuses.user_timeline(user_id=self.user_name, count=200, max_id=tweet_ids[-1])
            for tweet in range(len(timeline)):
        
                text = timeline[tweet]['text'].replace('"', '\'')
                tweet_id = int(timeline[tweet]['id'])
                date = self.__get_date(timeline, tweet)
                
                if keywords:
                    for k in keywords:
                        if self.__check_keyword(text,k):
                            self.df.loc[counter,'tweet'] = text
                            self.df.loc[counter,'timestamp'] = date
                            try:
                                self.df.loc[counter,'keywords'].append(k)
                            except AttributeError:
                                self.df.loc[counter,'keywords'] = [k]
                    try:
                        self.df.loc[counter,'keywords'] = ';'.join(self.df.loc[counter,'keywords'])
                    except KeyError:
                        pass
                        
                    
                else:
                    self.df.loc[counter,'tweet'] = text
                    self.df.loc[counter,'timestamp'] = date
                              
                counter += 1
                if max and counter >= max:
                    break
                
                sys.stdout.flush()   
                sys.stdout.write('\rTweets downloaded: %s' %counter)   
                    
            if max and counter >= max:
                break
            last_count = len(timeline)
            tweet_ids.append(timeline[-1]['id'])
            time.sleep(1)
        print()
        
    def make_csv(self, path):
        self.df.to_csv(path, encoding='utf8')

    def __get_date(self, timeline, tweet):
        timest = datetime.strptime(timeline[tweet]['created_at'],
                                      "%a %b %d %H:%M:%S +0000 %Y")
        date = timest.strftime("%Y-%d-%m %H:%M:%S")
        return date
    
    def __check_keyword(self, s, key):
        return bool(re.search(key, s, re.IGNORECASE))

# %%
tm = twitter_timeline.TimelineMiner(ACCESS_TOKEN, 
                                    ACCESS_TOKEN_SECRET,  
                                    CONSUMER_KEY, 
                                    CONSUMER_SECRET,
                                    USER_NAME)

print('Authentification successful: %s' %tm.authenticate())
tm.get_timeline(max=2000, keywords=[])
# Out:
# Authentification successful: True
# Tweets downloaded: 1
# Tweets downloaded: 2
# Tweets downloaded: 3
# Tweets downloaded: 4
# Tweets downloaded: 5
# Tweets downloaded: 6
# Tweets downloaded: 7
# Tweets downloaded: 8
# Tweets downloaded: 9
# Tweets downloaded: 10
# Tweets downloaded: 11
# Tweets downloaded: 12
# Tweets downloaded: 13
# Tweets downloaded: 14
# Tweets downloaded: 15
# Tweets downloaded: 16
# Tweets downloaded: 17
# Tweets downloaded: 18
# Tweets downloaded: 19
# Tweets downloaded: 20
# Tweets downloaded: 21
# Tweets downloaded: 22
# Tweets downloaded: 23
# Tweets downloaded: 24
# Tweets downloaded: 25
# Tweets downloaded: 26
# Tweets downloaded: 27
# Tweets downloaded: 28
# Tweets downloaded: 29
# Tweets downloaded: 30
# Tweets downloaded: 31
# Tweets downloaded: 32
# Tweets downloaded: 33
# Tweets downloaded: 34
# Tweets downloaded: 35
# Tweets downloaded: 36
# Tweets downloaded: 37
# Tweets downloaded: 38
# Tweets downloaded: 39
# Tweets downloaded: 40
# Tweets downloaded: 41
# Tweets downloaded: 42
# Tweets downloaded: 43
# Tweets downloaded: 44
# Tweets downloaded: 45
# Tweets downloaded: 46
# Tweets downloaded: 47
# Tweets downloaded: 48
# Tweets downloaded: 49
# Tweets downloaded: 50
# Tweets downloaded: 51
# Tweets downloaded: 52
# Tweets downloaded: 53
# Tweets downloaded: 54
# Tweets downloaded: 55
# Tweets downloaded: 56
# Tweets downloaded: 57
# Tweets downloaded: 58
# Tweets downloaded: 59
# Tweets downloaded: 60
# Tweets downloaded: 61
# Tweets downloaded: 62
# Tweets downloaded: 63
# Tweets downloaded: 64
# Tweets downloaded: 65
# Tweets downloaded: 66
# Tweets downloaded: 67
# Tweets downloaded: 68
# Tweets downloaded: 69
# Tweets downloaded: 70
# Tweets downloaded: 71
# Tweets downloaded: 72
# Tweets downloaded: 73
# Tweets downloaded: 74
# Tweets downloaded: 75
# Tweets downloaded: 76
# Tweets downloaded: 77
# Tweets downloaded: 78
# Tweets downloaded: 79
# Tweets downloaded: 80
# Tweets downloaded: 81
# Tweets downloaded: 82
# Tweets downloaded: 83
# Tweets downloaded: 84
# Tweets downloaded: 85
# Tweets downloaded: 86
# Tweets downloaded: 87
# Tweets downloaded: 88
# Tweets downloaded: 89
# Tweets downloaded: 90
# Tweets downloaded: 91
# Tweets downloaded: 92
# Tweets downloaded: 93
# Tweets downloaded: 94
# Tweets downloaded: 95
# Tweets downloaded: 96
# Tweets downloaded: 97
# Tweets downloaded: 98
# Tweets downloaded: 99
# Tweets downloaded: 100
# Tweets downloaded: 101
# Tweets downloaded: 102
# Tweets downloaded: 103
# Tweets downloaded: 104
# Tweets downloaded: 105
# Tweets downloaded: 106
# Tweets downloaded: 107
# Tweets downloaded: 108
# Tweets downloaded: 109
# Tweets downloaded: 110
# Tweets downloaded: 111
# Tweets downloaded: 112
# Tweets downloaded: 113
# Tweets downloaded: 114
# Tweets downloaded: 115
# Tweets downloaded: 116
# Tweets downloaded: 117
# Tweets downloaded: 118
# Tweets downloaded: 119
# Tweets downloaded: 120
# Tweets downloaded: 121
# Tweets downloaded: 122
# Tweets downloaded: 123
# Tweets downloaded: 124
# Tweets downloaded: 125
# Tweets downloaded: 126
# Tweets downloaded: 127
# Tweets downloaded: 128
# Tweets downloaded: 129
# Tweets downloaded: 130
# Tweets downloaded: 131
# Tweets downloaded: 132
# Tweets downloaded: 133
# Tweets downloaded: 134
# Tweets downloaded: 135
# Tweets downloaded: 136
# Tweets downloaded: 137
# Tweets downloaded: 138
# Tweets downloaded: 139
# Tweets downloaded: 140
# Tweets downloaded: 141
# Tweets downloaded: 142
# Tweets downloaded: 143
# Tweets downloaded: 144
# Tweets downloaded: 145
# Tweets downloaded: 146
# Tweets downloaded: 147
# Tweets downloaded: 148
# Tweets downloaded: 149
# Tweets downloaded: 150
# Tweets downloaded: 151
# Tweets downloaded: 152
# Tweets downloaded: 153
# Tweets downloaded: 154
# Tweets downloaded: 155
# Tweets downloaded: 156
# Tweets downloaded: 157
# Tweets downloaded: 158
# Tweets downloaded: 159
# Tweets downloaded: 160
# Tweets downloaded: 161
# Tweets downloaded: 162
# Tweets downloaded: 163
# Tweets downloaded: 164
# Tweets downloaded: 165
# Tweets downloaded: 166
# Tweets downloaded: 167
# Tweets downloaded: 168
# Tweets downloaded: 169
# Tweets downloaded: 170
# Tweets downloaded: 171
# Tweets downloaded: 172
# Tweets downloaded: 173
# Tweets downloaded: 174
# Tweets downloaded: 175
# Tweets downloaded: 176
# Tweets downloaded: 177
# Tweets downloaded: 178
# Tweets downloaded: 179
# Tweets downloaded: 180
# Tweets downloaded: 181
# Tweets downloaded: 182
# Tweets downloaded: 183
# Tweets downloaded: 184
# Tweets downloaded: 185
# Tweets downloaded: 186
# Tweets downloaded: 187
# Tweets downloaded: 188
# Tweets downloaded: 189
# Tweets downloaded: 190
# Tweets downloaded: 191
# Tweets downloaded: 192
# Tweets downloaded: 193
# Tweets downloaded: 194
# Tweets downloaded: 195
# Tweets downloaded: 196
# Tweets downloaded: 197
# Tweets downloaded: 198
# Tweets downloaded: 199
# Tweets downloaded: 200
# Tweets downloaded: 201
# Tweets downloaded: 202
# Tweets downloaded: 203
# Tweets downloaded: 204
# Tweets downloaded: 205
# Tweets downloaded: 206
# Tweets downloaded: 207
# Tweets downloaded: 208
# Tweets downloaded: 209
# Tweets downloaded: 210
# Tweets downloaded: 211
# Tweets downloaded: 212
# Tweets downloaded: 213
# Tweets downloaded: 214
# Tweets downloaded: 215
# Tweets downloaded: 216
# Tweets downloaded: 217
# Tweets downloaded: 218
# Tweets downloaded: 219
# Tweets downloaded: 220
# Tweets downloaded: 221
# Tweets downloaded: 222
# Tweets downloaded: 223
# Tweets downloaded: 224
# Tweets downloaded: 225
# Tweets downloaded: 226
# Tweets downloaded: 227
# Tweets downloaded: 228
# Tweets downloaded: 229
# Tweets downloaded: 230
# Tweets downloaded: 231
# Tweets downloaded: 232
# Tweets downloaded: 233
# Tweets downloaded: 234
# Tweets downloaded: 235
# Tweets downloaded: 236
# Tweets downloaded: 237
# Tweets downloaded: 238
# Tweets downloaded: 239
# Tweets downloaded: 240
# Tweets downloaded: 241
# Tweets downloaded: 242
# Tweets downloaded: 243
# Tweets downloaded: 244
# Tweets downloaded: 245
# Tweets downloaded: 246
# Tweets downloaded: 247
# Tweets downloaded: 248
# Tweets downloaded: 249
# Tweets downloaded: 250
# Tweets downloaded: 251
# Tweets downloaded: 252
# Tweets downloaded: 253
# Tweets downloaded: 254
# Tweets downloaded: 255
# Tweets downloaded: 256
# Tweets downloaded: 257
# Tweets downloaded: 258
# Tweets downloaded: 259
# Tweets downloaded: 260
# Tweets downloaded: 261
# Tweets downloaded: 262
# Tweets downloaded: 263
# Tweets downloaded: 264
# Tweets downloaded: 265
# Tweets downloaded: 266
# Tweets downloaded: 267
# Tweets downloaded: 268
# Tweets downloaded: 269
# Tweets downloaded: 270
# Tweets downloaded: 271
# Tweets downloaded: 272
# Tweets downloaded: 273
# Tweets downloaded: 274
# Tweets downloaded: 275
# Tweets downloaded: 276
# Tweets downloaded: 277
# Tweets downloaded: 278
# Tweets downloaded: 279
# Tweets downloaded: 280
# Tweets downloaded: 281
# Tweets downloaded: 282
# Tweets downloaded: 283
# Tweets downloaded: 284
# Tweets downloaded: 285
# Tweets downloaded: 286
# Tweets downloaded: 287
# Tweets downloaded: 288
# Tweets downloaded: 289
# Tweets downloaded: 290
# Tweets downloaded: 291
# Tweets downloaded: 292
# Tweets downloaded: 293
# Tweets downloaded: 294
# Tweets downloaded: 295
# Tweets downloaded: 296
# Tweets downloaded: 297
# Tweets downloaded: 298
# Tweets downloaded: 299
# Tweets downloaded: 300
# Tweets downloaded: 301
# Tweets downloaded: 302
# Tweets downloaded: 303
# Tweets downloaded: 304
# Tweets downloaded: 305
# Tweets downloaded: 306
# Tweets downloaded: 307
# Tweets downloaded: 308
# Tweets downloaded: 309
# Tweets downloaded: 310
# Tweets downloaded: 311
# Tweets downloaded: 312
# Tweets downloaded: 313
# Tweets downloaded: 314
# Tweets downloaded: 315
# Tweets downloaded: 316
# Tweets downloaded: 317
# Tweets downloaded: 318
# Tweets downloaded: 319
# Tweets downloaded: 320
# Tweets downloaded: 321
# Tweets downloaded: 322
# Tweets downloaded: 323
# Tweets downloaded: 324
# Tweets downloaded: 325
# Tweets downloaded: 326
# Tweets downloaded: 327
# Tweets downloaded: 328
# Tweets downloaded: 329
# Tweets downloaded: 330
# Tweets downloaded: 331
# Tweets downloaded: 332
# Tweets downloaded: 333
# Tweets downloaded: 334
# Tweets downloaded: 335
# Tweets downloaded: 336
# Tweets downloaded: 337
# Tweets downloaded: 338
# Tweets downloaded: 339
# Tweets downloaded: 340
# Tweets downloaded: 341
# Tweets downloaded: 342
# Tweets downloaded: 343
# Tweets downloaded: 344
# Tweets downloaded: 345
# Tweets downloaded: 346
# Tweets downloaded: 347
# Tweets downloaded: 348
# Tweets downloaded: 349
# Tweets downloaded: 350
# Tweets downloaded: 351
# Tweets downloaded: 352
# Tweets downloaded: 353
# Tweets downloaded: 354
# Tweets downloaded: 355
# Tweets downloaded: 356
# Tweets downloaded: 357
# Tweets downloaded: 358
# Tweets downloaded: 359
# Tweets downloaded: 360
# Tweets downloaded: 361
# Tweets downloaded: 362
# Tweets downloaded: 363
# Tweets downloaded: 364
# Tweets downloaded: 365
# Tweets downloaded: 366
# Tweets downloaded: 367
# Tweets downloaded: 368
# Tweets downloaded: 369
# Tweets downloaded: 370
# Tweets downloaded: 371
# Tweets downloaded: 372
# Tweets downloaded: 373
# Tweets downloaded: 374
# Tweets downloaded: 375
# Tweets downloaded: 376
# Tweets downloaded: 377
# Tweets downloaded: 378
# Tweets downloaded: 379
# Tweets downloaded: 380
# Tweets downloaded: 381
# Tweets downloaded: 382
# Tweets downloaded: 383
# Tweets downloaded: 384
# Tweets downloaded: 385
# Tweets downloaded: 386
# Tweets downloaded: 387
# Tweets downloaded: 388
# Tweets downloaded: 389
# Tweets downloaded: 390
# Tweets downloaded: 391
# Tweets downloaded: 392
# Tweets downloaded: 393
# Tweets downloaded: 394
# Tweets downloaded: 395
# Tweets downloaded: 396
# Tweets downloaded: 397
# Tweets downloaded: 398
# Tweets downloaded: 399
# Tweets downloaded: 400
# Tweets downloaded: 401
# Tweets downloaded: 402
# Tweets downloaded: 403
# Tweets downloaded: 404
# Tweets downloaded: 405
# Tweets downloaded: 406
# Tweets downloaded: 407
# Tweets downloaded: 408
# Tweets downloaded: 409
# Tweets downloaded: 410
# Tweets downloaded: 411
# Tweets downloaded: 412
# Tweets downloaded: 413
# Tweets downloaded: 414
# Tweets downloaded: 415
# Tweets downloaded: 416
# Tweets downloaded: 417
# Tweets downloaded: 418
# Tweets downloaded: 419
# Tweets downloaded: 420
# Tweets downloaded: 421
# Tweets downloaded: 422
# Tweets downloaded: 423
# Tweets downloaded: 424
# Tweets downloaded: 425
# Tweets downloaded: 426
# Tweets downloaded: 427
# Tweets downloaded: 428
# Tweets downloaded: 429
# Tweets downloaded: 430
# Tweets downloaded: 431
# Tweets downloaded: 432
# Tweets downloaded: 433
# Tweets downloaded: 434
# Tweets downloaded: 435
# Tweets downloaded: 436
# Tweets downloaded: 437
# Tweets downloaded: 438
# Tweets downloaded: 439
# Tweets downloaded: 440
# Tweets downloaded: 441
# Tweets downloaded: 442
# Tweets downloaded: 443
# Tweets downloaded: 444
# Tweets downloaded: 445
# Tweets downloaded: 446
# Tweets downloaded: 447
# Tweets downloaded: 448
# Tweets downloaded: 449
# Tweets downloaded: 450
# Tweets downloaded: 451
# Tweets downloaded: 452
# Tweets downloaded: 453
# Tweets downloaded: 454
# Tweets downloaded: 455
# Tweets downloaded: 456
# Tweets downloaded: 457
# Tweets downloaded: 458
# Tweets downloaded: 459
# Tweets downloaded: 460
# Tweets downloaded: 461
# Tweets downloaded: 462
# Tweets downloaded: 463
# Tweets downloaded: 464
# Tweets downloaded: 465
# Tweets downloaded: 466
# Tweets downloaded: 467
# Tweets downloaded: 468
# Tweets downloaded: 469
# Tweets downloaded: 470
# Tweets downloaded: 471
# Tweets downloaded: 472
# Tweets downloaded: 473
# Tweets downloaded: 474
# Tweets downloaded: 475
# Tweets downloaded: 476
# Tweets downloaded: 477
# Tweets downloaded: 478
# Tweets downloaded: 479
# Tweets downloaded: 480
# Tweets downloaded: 481
# Tweets downloaded: 482
# Tweets downloaded: 483
# Tweets downloaded: 484
# Tweets downloaded: 485
# Tweets downloaded: 486
# Tweets downloaded: 487
# Tweets downloaded: 488
# Tweets downloaded: 489
# Tweets downloaded: 490
# Tweets downloaded: 491
# Tweets downloaded: 492
# Tweets downloaded: 493
# Tweets downloaded: 494
# Tweets downloaded: 495
# Tweets downloaded: 496
# Tweets downloaded: 497
# Tweets downloaded: 498
# Tweets downloaded: 499
# Tweets downloaded: 500
# Tweets downloaded: 501
# Tweets downloaded: 502
# Tweets downloaded: 503
# Tweets downloaded: 504
# Tweets downloaded: 505
# Tweets downloaded: 506
# Tweets downloaded: 507
# Tweets downloaded: 508
# Tweets downloaded: 509
# Tweets downloaded: 510
# Tweets downloaded: 511
# Tweets downloaded: 512
# Tweets downloaded: 513
# Tweets downloaded: 514
# Tweets downloaded: 515
# Tweets downloaded: 516
# Tweets downloaded: 517
# Tweets downloaded: 518
# Tweets downloaded: 519
# Tweets downloaded: 520
# Tweets downloaded: 521
# Tweets downloaded: 522
# Tweets downloaded: 523
# Tweets downloaded: 524
# Tweets downloaded: 525
# Tweets downloaded: 526
# Tweets downloaded: 527
# Tweets downloaded: 528
# Tweets downloaded: 529
# Tweets downloaded: 530
# Tweets downloaded: 531
# Tweets downloaded: 532
# Tweets downloaded: 533
# Tweets downloaded: 534
# Tweets downloaded: 535
# Tweets downloaded: 536
# Tweets downloaded: 537
# Tweets downloaded: 538
# Tweets downloaded: 539
# Tweets downloaded: 540
# Tweets downloaded: 541
# Tweets downloaded: 542
# Tweets downloaded: 543
# Tweets downloaded: 544
# Tweets downloaded: 545
# Tweets downloaded: 546
# Tweets downloaded: 547
# Tweets downloaded: 548
# Tweets downloaded: 549
# Tweets downloaded: 550
# Tweets downloaded: 551
# Tweets downloaded: 552
# Tweets downloaded: 553
# Tweets downloaded: 554
# Tweets downloaded: 555
# Tweets downloaded: 556
# Tweets downloaded: 557
# Tweets downloaded: 558
# Tweets downloaded: 559
# Tweets downloaded: 560
# Tweets downloaded: 561
# Tweets downloaded: 562
# Tweets downloaded: 563
# Tweets downloaded: 564
# Tweets downloaded: 565
# Tweets downloaded: 566
# Tweets downloaded: 567
# Tweets downloaded: 568
# Tweets downloaded: 569
# Tweets downloaded: 570
# Tweets downloaded: 571
# Tweets downloaded: 572
# Tweets downloaded: 573
# Tweets downloaded: 574
# Tweets downloaded: 575
# Tweets downloaded: 576
# Tweets downloaded: 577
# Tweets downloaded: 578
# Tweets downloaded: 579
# Tweets downloaded: 580
# Tweets downloaded: 581
# Tweets downloaded: 582
# Tweets downloaded: 583
# Tweets downloaded: 584
# Tweets downloaded: 585
# Tweets downloaded: 586
# Tweets downloaded: 587
# Tweets downloaded: 588
# Tweets downloaded: 589
# Tweets downloaded: 590
# Tweets downloaded: 591
# Tweets downloaded: 592
# Tweets downloaded: 593
# Tweets downloaded: 594
# Tweets downloaded: 595
# Tweets downloaded: 596
# Tweets downloaded: 597
# Tweets downloaded: 598
# Tweets downloaded: 599
# Tweets downloaded: 600
# Tweets downloaded: 601
# Tweets downloaded: 602
# Tweets downloaded: 603
# Tweets downloaded: 604
# Tweets downloaded: 605
# Tweets downloaded: 606
# Tweets downloaded: 607
# Tweets downloaded: 608
# Tweets downloaded: 609
# Tweets downloaded: 610
# Tweets downloaded: 611
# Tweets downloaded: 612
# Tweets downloaded: 613
# Tweets downloaded: 614
# Tweets downloaded: 615
# Tweets downloaded: 616
# Tweets downloaded: 617
# Tweets downloaded: 618
# Tweets downloaded: 619
# Tweets downloaded: 620
# Tweets downloaded: 621
# Tweets downloaded: 622
# Tweets downloaded: 623
# Tweets downloaded: 624
# Tweets downloaded: 625
# Tweets downloaded: 626
# Tweets downloaded: 627
# Tweets downloaded: 628
# Tweets downloaded: 629
# Tweets downloaded: 630
# Tweets downloaded: 631
# Tweets downloaded: 632
# Tweets downloaded: 633
# Tweets downloaded: 634
# Tweets downloaded: 635
# Tweets downloaded: 636
# Tweets downloaded: 637
# Tweets downloaded: 638
# Tweets downloaded: 639
# Tweets downloaded: 640
# Tweets downloaded: 641
# Tweets downloaded: 642
# Tweets downloaded: 643
# Tweets downloaded: 644
# Tweets downloaded: 645
# Tweets downloaded: 646
# Tweets downloaded: 647
# Tweets downloaded: 648
# Tweets downloaded: 649
# Tweets downloaded: 650
# Tweets downloaded: 651
# Tweets downloaded: 652
# Tweets downloaded: 653
# Tweets downloaded: 654
# Tweets downloaded: 655
# Tweets downloaded: 656
# Tweets downloaded: 657
# Tweets downloaded: 658
# Tweets downloaded: 659
# Tweets downloaded: 660
# Tweets downloaded: 661
# Tweets downloaded: 662
# Tweets downloaded: 663
# Tweets downloaded: 664
# Tweets downloaded: 665
# Tweets downloaded: 666
# Tweets downloaded: 667
# Tweets downloaded: 668
# Tweets downloaded: 669
# Tweets downloaded: 670
# Tweets downloaded: 671
# Tweets downloaded: 672
# Tweets downloaded: 673
# Tweets downloaded: 674
# Tweets downloaded: 675
# Tweets downloaded: 676
# Tweets downloaded: 677
# Tweets downloaded: 678
# Tweets downloaded: 679
# Tweets downloaded: 680
# Tweets downloaded: 681
# Tweets downloaded: 682
# Tweets downloaded: 683
# Tweets downloaded: 684
# Tweets downloaded: 685
# Tweets downloaded: 686
# Tweets downloaded: 687
# Tweets downloaded: 688
# Tweets downloaded: 689
# Tweets downloaded: 690
# Tweets downloaded: 691
# Tweets downloaded: 692
# Tweets downloaded: 693
# Tweets downloaded: 694
# Tweets downloaded: 695
# Tweets downloaded: 696
# Tweets downloaded: 697
# Tweets downloaded: 698
# Tweets downloaded: 699
# Tweets downloaded: 700
# Tweets downloaded: 701
# Tweets downloaded: 702
# Tweets downloaded: 703
# Tweets downloaded: 704
# Tweets downloaded: 705
# Tweets downloaded: 706
# Tweets downloaded: 707
# Tweets downloaded: 708
# Tweets downloaded: 709
# Tweets downloaded: 710
# Tweets downloaded: 711
# Tweets downloaded: 712
# Tweets downloaded: 713
# Tweets downloaded: 714
# Tweets downloaded: 715
# Tweets downloaded: 716
# Tweets downloaded: 717
# Tweets downloaded: 718
# Tweets downloaded: 719
# Tweets downloaded: 720
# Tweets downloaded: 721
# Tweets downloaded: 722
# Tweets downloaded: 723
# Tweets downloaded: 724
# Tweets downloaded: 725
# Tweets downloaded: 726
# Tweets downloaded: 727
# Tweets downloaded: 728
# Tweets downloaded: 729
# Tweets downloaded: 730
# Tweets downloaded: 731
# Tweets downloaded: 732
# Tweets downloaded: 733
# Tweets downloaded: 734
# Tweets downloaded: 735
# Tweets downloaded: 736
# Tweets downloaded: 737
# Tweets downloaded: 738
# Tweets downloaded: 739
# Tweets downloaded: 740
# Tweets downloaded: 741
# Tweets downloaded: 742
# Tweets downloaded: 743
# Tweets downloaded: 744
# Tweets downloaded: 745
# Tweets downloaded: 746
# Tweets downloaded: 747
# Tweets downloaded: 748
# Tweets downloaded: 749
# Tweets downloaded: 750
# Tweets downloaded: 751
# Tweets downloaded: 752
# Tweets downloaded: 753
# Tweets downloaded: 754
# Tweets downloaded: 755
# Tweets downloaded: 756
# Tweets downloaded: 757
# Tweets downloaded: 758
# Tweets downloaded: 759
# Tweets downloaded: 760
# Tweets downloaded: 761
# Tweets downloaded: 762
# Tweets downloaded: 763
# Tweets downloaded: 764
# Tweets downloaded: 765
# Tweets downloaded: 766
# Tweets downloaded: 767
# Tweets downloaded: 768
# Tweets downloaded: 769
# Tweets downloaded: 770
# Tweets downloaded: 771
# Tweets downloaded: 772
# Tweets downloaded: 773
# Tweets downloaded: 774
# Tweets downloaded: 775
# Tweets downloaded: 776
# Tweets downloaded: 777
# Tweets downloaded: 778
# Tweets downloaded: 779
# Tweets downloaded: 780
# Tweets downloaded: 781
# Tweets downloaded: 782
# Tweets downloaded: 783
# Tweets downloaded: 784
# Tweets downloaded: 785
# Tweets downloaded: 786
# Tweets downloaded: 787
# Tweets downloaded: 788
# Tweets downloaded: 789
# Tweets downloaded: 790
# Tweets downloaded: 791
# Tweets downloaded: 792
# Tweets downloaded: 793
# Tweets downloaded: 794
# Tweets downloaded: 795
# Tweets downloaded: 796
# Tweets downloaded: 797
# Tweets downloaded: 798
# Tweets downloaded: 799
# Tweets downloaded: 800
# Tweets downloaded: 801
# Tweets downloaded: 802
# Tweets downloaded: 803
# Tweets downloaded: 804
# Tweets downloaded: 805
# Tweets downloaded: 806
# Tweets downloaded: 807
# Tweets downloaded: 808
# Tweets downloaded: 809
# Tweets downloaded: 810
# Tweets downloaded: 811
# Tweets downloaded: 812
# Tweets downloaded: 813
# Tweets downloaded: 814
# Tweets downloaded: 815
# Tweets downloaded: 816
# Tweets downloaded: 817
# Tweets downloaded: 818
# Tweets downloaded: 819
# Tweets downloaded: 820
# Tweets downloaded: 821
# Tweets downloaded: 822
# Tweets downloaded: 823
# Tweets downloaded: 824
# Tweets downloaded: 825
# Tweets downloaded: 826
# Tweets downloaded: 827
# Tweets downloaded: 828
# Tweets downloaded: 829
# Tweets downloaded: 830
# Tweets downloaded: 831
# Tweets downloaded: 832
# Tweets downloaded: 833
# Tweets downloaded: 834
# Tweets downloaded: 835
# Tweets downloaded: 836
# Tweets downloaded: 837
# Tweets downloaded: 838
# Tweets downloaded: 839
# Tweets downloaded: 840
# Tweets downloaded: 841
# Tweets downloaded: 842
# Tweets downloaded: 843
# Tweets downloaded: 844
# Tweets downloaded: 845
# Tweets downloaded: 846
# Tweets downloaded: 847
# Tweets downloaded: 848
# Tweets downloaded: 849
# Tweets downloaded: 850
# Tweets downloaded: 851
# Tweets downloaded: 852
# Tweets downloaded: 853
# Tweets downloaded: 854
# Tweets downloaded: 855
# Tweets downloaded: 856
# Tweets downloaded: 857
# Tweets downloaded: 858
# Tweets downloaded: 859
# Tweets downloaded: 860
# Tweets downloaded: 861
# Tweets downloaded: 862
# Tweets downloaded: 863
# Tweets downloaded: 864
# Tweets downloaded: 865
# Tweets downloaded: 866
# Tweets downloaded: 867
# Tweets downloaded: 868
# Tweets downloaded: 869
# Tweets downloaded: 870
# Tweets downloaded: 871
# Tweets downloaded: 872
# Tweets downloaded: 873
# Tweets downloaded: 874
# Tweets downloaded: 875
# Tweets downloaded: 876
# Tweets downloaded: 877
# Tweets downloaded: 878
# Tweets downloaded: 879
# Tweets downloaded: 880
# Tweets downloaded: 881
# Tweets downloaded: 882
# Tweets downloaded: 883
# Tweets downloaded: 884
# Tweets downloaded: 885
# Tweets downloaded: 886
# Tweets downloaded: 887
# Tweets downloaded: 888
# Tweets downloaded: 889
# Tweets downloaded: 890
# Tweets downloaded: 891
# Tweets downloaded: 892
# Tweets downloaded: 893
# Tweets downloaded: 894
# Tweets downloaded: 895
# Tweets downloaded: 896
# Tweets downloaded: 897
# Tweets downloaded: 898
# Tweets downloaded: 899
# Tweets downloaded: 900
# Tweets downloaded: 901
# Tweets downloaded: 902
# Tweets downloaded: 903
# Tweets downloaded: 904
# Tweets downloaded: 905
# Tweets downloaded: 906
# Tweets downloaded: 907
# Tweets downloaded: 908
# Tweets downloaded: 909
# Tweets downloaded: 910
# Tweets downloaded: 911
# Tweets downloaded: 912
# Tweets downloaded: 913
# Tweets downloaded: 914
# Tweets downloaded: 915
# Tweets downloaded: 916
# Tweets downloaded: 917
# Tweets downloaded: 918
# Tweets downloaded: 919
# Tweets downloaded: 920
# Tweets downloaded: 921
# Tweets downloaded: 922
# Tweets downloaded: 923
# Tweets downloaded: 924
# Tweets downloaded: 925
# Tweets downloaded: 926
# Tweets downloaded: 927
# Tweets downloaded: 928
# Tweets downloaded: 929
# Tweets downloaded: 930
# Tweets downloaded: 931
# Tweets downloaded: 932
# Tweets downloaded: 933
# Tweets downloaded: 934
# Tweets downloaded: 935
# Tweets downloaded: 936
# Tweets downloaded: 937
# Tweets downloaded: 938
# Tweets downloaded: 939
# Tweets downloaded: 940
# Tweets downloaded: 941
# Tweets downloaded: 942
# Tweets downloaded: 943
# Tweets downloaded: 944
# Tweets downloaded: 945
# Tweets downloaded: 946
# Tweets downloaded: 947
# Tweets downloaded: 948
# Tweets downloaded: 949
# Tweets downloaded: 950
# Tweets downloaded: 951
# Tweets downloaded: 952
# Tweets downloaded: 953
# Tweets downloaded: 954
# Tweets downloaded: 955
# Tweets downloaded: 956
# Tweets downloaded: 957
# Tweets downloaded: 958
# Tweets downloaded: 959
# Tweets downloaded: 960
# Tweets downloaded: 961
# Tweets downloaded: 962
# Tweets downloaded: 963
# Tweets downloaded: 964
# Tweets downloaded: 965
# Tweets downloaded: 966
# Tweets downloaded: 967
# Tweets downloaded: 968
# Tweets downloaded: 969
# Tweets downloaded: 970
# Tweets downloaded: 971
# Tweets downloaded: 972
# Tweets downloaded: 973
# Tweets downloaded: 974
# Tweets downloaded: 975
# Tweets downloaded: 976
# Tweets downloaded: 977
# Tweets downloaded: 978
# Tweets downloaded: 979
# Tweets downloaded: 980
# Tweets downloaded: 981
# Tweets downloaded: 982
# Tweets downloaded: 983
# Tweets downloaded: 984
# Tweets downloaded: 985
# Tweets downloaded: 986
# Tweets downloaded: 987
# Tweets downloaded: 988
# Tweets downloaded: 989
# Tweets downloaded: 990
# Tweets downloaded: 991
# Tweets downloaded: 992
# Tweets downloaded: 993
# Tweets downloaded: 994
# Tweets downloaded: 995
# Tweets downloaded: 996
# Tweets downloaded: 997
# Tweets downloaded: 998
# Tweets downloaded: 999
# Tweets downloaded: 1000
# Tweets downloaded: 1001
# Tweets downloaded: 1002
# Tweets downloaded: 1003
# Tweets downloaded: 1004
# Tweets downloaded: 1005
# Tweets downloaded: 1006
# Tweets downloaded: 1007
# Tweets downloaded: 1008
# Tweets downloaded: 1009
# Tweets downloaded: 1010
# Tweets downloaded: 1011
# Tweets downloaded: 1012
# Tweets downloaded: 1013
# Tweets downloaded: 1014
# Tweets downloaded: 1015
# Tweets downloaded: 1016
# Tweets downloaded: 1017
# Tweets downloaded: 1018
# Tweets downloaded: 1019
# Tweets downloaded: 1020
# Tweets downloaded: 1021
# Tweets downloaded: 1022
# Tweets downloaded: 1023
# Tweets downloaded: 1024
# Tweets downloaded: 1025
# Tweets downloaded: 1026
# Tweets downloaded: 1027
# Tweets downloaded: 1028
# Tweets downloaded: 1029
# Tweets downloaded: 1030
# Tweets downloaded: 1031
# Tweets downloaded: 1032
# Tweets downloaded: 1033
# Tweets downloaded: 1034
# Tweets downloaded: 1035
# Tweets downloaded: 1036
# Tweets downloaded: 1037
# Tweets downloaded: 1038
# Tweets downloaded: 1039
# Tweets downloaded: 1040
# Tweets downloaded: 1041
# Tweets downloaded: 1042
# Tweets downloaded: 1043
# Tweets downloaded: 1044
# Tweets downloaded: 1045
# Tweets downloaded: 1046
# Tweets downloaded: 1047
# Tweets downloaded: 1048
# Tweets downloaded: 1049
# Tweets downloaded: 1050
# Tweets downloaded: 1051
# Tweets downloaded: 1052
# Tweets downloaded: 1053
# Tweets downloaded: 1054
# Tweets downloaded: 1055
# Tweets downloaded: 1056
# Tweets downloaded: 1057
# Tweets downloaded: 1058
# Tweets downloaded: 1059
# Tweets downloaded: 1060
# Tweets downloaded: 1061
# Tweets downloaded: 1062
# Tweets downloaded: 1063
# Tweets downloaded: 1064
# Tweets downloaded: 1065
# Tweets downloaded: 1066
# Tweets downloaded: 1067
# Tweets downloaded: 1068
# Tweets downloaded: 1069
# Tweets downloaded: 1070
# Tweets downloaded: 1071
# Tweets downloaded: 1072
# Tweets downloaded: 1073
# Tweets downloaded: 1074
# Tweets downloaded: 1075
# Tweets downloaded: 1076
# Tweets downloaded: 1077
# Tweets downloaded: 1078
# Tweets downloaded: 1079
# Tweets downloaded: 1080
# Tweets downloaded: 1081
# Tweets downloaded: 1082
# Tweets downloaded: 1083
# Tweets downloaded: 1084
# Tweets downloaded: 1085
# Tweets downloaded: 1086
# Tweets downloaded: 1087
# Tweets downloaded: 1088
# Tweets downloaded: 1089
# Tweets downloaded: 1090
# Tweets downloaded: 1091
# Tweets downloaded: 1092
# Tweets downloaded: 1093
# Tweets downloaded: 1094
# Tweets downloaded: 1095
# Tweets downloaded: 1096
# Tweets downloaded: 1097
# Tweets downloaded: 1098
# Tweets downloaded: 1099
# Tweets downloaded: 1100
# Tweets downloaded: 1101
# Tweets downloaded: 1102
# Tweets downloaded: 1103
# Tweets downloaded: 1104
# Tweets downloaded: 1105
# Tweets downloaded: 1106
# Tweets downloaded: 1107
# Tweets downloaded: 1108
# Tweets downloaded: 1109
# Tweets downloaded: 1110
# Tweets downloaded: 1111
# Tweets downloaded: 1112
# Tweets downloaded: 1113
# Tweets downloaded: 1114
# Tweets downloaded: 1115
# Tweets downloaded: 1116
# Tweets downloaded: 1117
# Tweets downloaded: 1118
# Tweets downloaded: 1119
# Tweets downloaded: 1120
# Tweets downloaded: 1121
# Tweets downloaded: 1122
# Tweets downloaded: 1123
# Tweets downloaded: 1124
# Tweets downloaded: 1125
# Tweets downloaded: 1126
# Tweets downloaded: 1127
# Tweets downloaded: 1128
# Tweets downloaded: 1129
# Tweets downloaded: 1130
# Tweets downloaded: 1131
# Tweets downloaded: 1132
# Tweets downloaded: 1133
# Tweets downloaded: 1134
# Tweets downloaded: 1135
# Tweets downloaded: 1136
# Tweets downloaded: 1137
# Tweets downloaded: 1138
# Tweets downloaded: 1139
# Tweets downloaded: 1140
# Tweets downloaded: 1141
# Tweets downloaded: 1142
# Tweets downloaded: 1143
# Tweets downloaded: 1144
# Tweets downloaded: 1145
# Tweets downloaded: 1146
# Tweets downloaded: 1147
# Tweets downloaded: 1148
# Tweets downloaded: 1149
# Tweets downloaded: 1150
# Tweets downloaded: 1151
# Tweets downloaded: 1152
# Tweets downloaded: 1153
# Tweets downloaded: 1154
# Tweets downloaded: 1155
# Tweets downloaded: 1156
# Tweets downloaded: 1157
# Tweets downloaded: 1158
# Tweets downloaded: 1159
# Tweets downloaded: 1160
# Tweets downloaded: 1161
# Tweets downloaded: 1162
# Tweets downloaded: 1163
# Tweets downloaded: 1164
# Tweets downloaded: 1165
# Tweets downloaded: 1166
# Tweets downloaded: 1167
# Tweets downloaded: 1168
# Tweets downloaded: 1169
# Tweets downloaded: 1170
# Tweets downloaded: 1171
# Tweets downloaded: 1172
# Tweets downloaded: 1173
# Tweets downloaded: 1174
# Tweets downloaded: 1175
# Tweets downloaded: 1176
# Tweets downloaded: 1177
# Tweets downloaded: 1178
# Tweets downloaded: 1179
# Tweets downloaded: 1180
# Tweets downloaded: 1181
# Tweets downloaded: 1182
# Tweets downloaded: 1183
# Tweets downloaded: 1184
# Tweets downloaded: 1185
# Tweets downloaded: 1186
# Tweets downloaded: 1187
# Tweets downloaded: 1188
# Tweets downloaded: 1189
# Tweets downloaded: 1190
# Tweets downloaded: 1191
# Tweets downloaded: 1192
# Tweets downloaded: 1193
# Tweets downloaded: 1194
# Tweets downloaded: 1195
# Tweets downloaded: 1196
# Tweets downloaded: 1197
# Tweets downloaded: 1198
# Tweets downloaded: 1199
# Tweets downloaded: 1200
# Tweets downloaded: 1201
# Tweets downloaded: 1202
# Tweets downloaded: 1203
# Tweets downloaded: 1204
# Tweets downloaded: 1205
# Tweets downloaded: 1206
# Tweets downloaded: 1207
# Tweets downloaded: 1208
# Tweets downloaded: 1209
# Tweets downloaded: 1210
# Tweets downloaded: 1211
# Tweets downloaded: 1212
# Tweets downloaded: 1213
# Tweets downloaded: 1214
# Tweets downloaded: 1215
# Tweets downloaded: 1216
# Tweets downloaded: 1217
# Tweets downloaded: 1218
# Tweets downloaded: 1219
# Tweets downloaded: 1220
# Tweets downloaded: 1221
# Tweets downloaded: 1222
# Tweets downloaded: 1223
# Tweets downloaded: 1224
# Tweets downloaded: 1225
# Tweets downloaded: 1226
# Tweets downloaded: 1227
# Tweets downloaded: 1228
# Tweets downloaded: 1229
# Tweets downloaded: 1230
# Tweets downloaded: 1231
# Tweets downloaded: 1232
# Tweets downloaded: 1233
# Tweets downloaded: 1234
# Tweets downloaded: 1235
# Tweets downloaded: 1236
# Tweets downloaded: 1237
# Tweets downloaded: 1238
# Tweets downloaded: 1239
# Tweets downloaded: 1240
# Tweets downloaded: 1241
# Tweets downloaded: 1242
# Tweets downloaded: 1243
# Tweets downloaded: 1244
# Tweets downloaded: 1245
# Tweets downloaded: 1246
# Tweets downloaded: 1247
# Tweets downloaded: 1248
# Tweets downloaded: 1249
# Tweets downloaded: 1250
# Tweets downloaded: 1251
# Tweets downloaded: 1252
# Tweets downloaded: 1253
# Tweets downloaded: 1254
# Tweets downloaded: 1255
# Tweets downloaded: 1256
# Tweets downloaded: 1257
# Tweets downloaded: 1258
# Tweets downloaded: 1259
# Tweets downloaded: 1260
# Tweets downloaded: 1261
# Tweets downloaded: 1262
# Tweets downloaded: 1263
# Tweets downloaded: 1264
# Tweets downloaded: 1265
# Tweets downloaded: 1266
# Tweets downloaded: 1267
# Tweets downloaded: 1268
# Tweets downloaded: 1269
# Tweets downloaded: 1270
# Tweets downloaded: 1271
# Tweets downloaded: 1272
# Tweets downloaded: 1273
# Tweets downloaded: 1274
# Tweets downloaded: 1275
# Tweets downloaded: 1276
# Tweets downloaded: 1277
# Tweets downloaded: 1278
# Tweets downloaded: 1279
# Tweets downloaded: 1280
# Tweets downloaded: 1281
# Tweets downloaded: 1282
# Tweets downloaded: 1283
# Tweets downloaded: 1284
# Tweets downloaded: 1285
# Tweets downloaded: 1286
# Tweets downloaded: 1287
# Tweets downloaded: 1288
# Tweets downloaded: 1289
# Tweets downloaded: 1290
# Tweets downloaded: 1291
# Tweets downloaded: 1292
# Tweets downloaded: 1293
# Tweets downloaded: 1294
# Tweets downloaded: 1295
# Tweets downloaded: 1296
# Tweets downloaded: 1297
# Tweets downloaded: 1298
# Tweets downloaded: 1299
# Tweets downloaded: 1300
# Tweets downloaded: 1301
# Tweets downloaded: 1302
# Tweets downloaded: 1303
# Tweets downloaded: 1304
# Tweets downloaded: 1305
# Tweets downloaded: 1306
# Tweets downloaded: 1307
# Tweets downloaded: 1308
# Tweets downloaded: 1309
# Tweets downloaded: 1310
# Tweets downloaded: 1311
# Tweets downloaded: 1312
# Tweets downloaded: 1313
# Tweets downloaded: 1314
# Tweets downloaded: 1315
# Tweets downloaded: 1316
# Tweets downloaded: 1317
# Tweets downloaded: 1318
# Tweets downloaded: 1319
# Tweets downloaded: 1320
# Tweets downloaded: 1321
# Tweets downloaded: 1322
# Tweets downloaded: 1323
# Tweets downloaded: 1324
# Tweets downloaded: 1325
# Tweets downloaded: 1326
# Tweets downloaded: 1327
# Tweets downloaded: 1328
# Tweets downloaded: 1329
# Tweets downloaded: 1330
# Tweets downloaded: 1331
# Tweets downloaded: 1332
# Tweets downloaded: 1333
# Tweets downloaded: 1334
# Tweets downloaded: 1335
# Tweets downloaded: 1336
# Tweets downloaded: 1337
# Tweets downloaded: 1338
# Tweets downloaded: 1339
# Tweets downloaded: 1340
# Tweets downloaded: 1341
# Tweets downloaded: 1342
# Tweets downloaded: 1343
# Tweets downloaded: 1344
# Tweets downloaded: 1345
# Tweets downloaded: 1346
# Tweets downloaded: 1347
# Tweets downloaded: 1348
# Tweets downloaded: 1349
# Tweets downloaded: 1350
# Tweets downloaded: 1351
# Tweets downloaded: 1352
# Tweets downloaded: 1353
# Tweets downloaded: 1354
# Tweets downloaded: 1355
# Tweets downloaded: 1356
# Tweets downloaded: 1357
# Tweets downloaded: 1358
# Tweets downloaded: 1359
# Tweets downloaded: 1360
# Tweets downloaded: 1361
# Tweets downloaded: 1362
# Tweets downloaded: 1363
# Tweets downloaded: 1364
# Tweets downloaded: 1365
# Tweets downloaded: 1366
# Tweets downloaded: 1367
# Tweets downloaded: 1368
# Tweets downloaded: 1369
# Tweets downloaded: 1370
# Tweets downloaded: 1371
# Tweets downloaded: 1372
# Tweets downloaded: 1373
# Tweets downloaded: 1374
# Tweets downloaded: 1375
# Tweets downloaded: 1376
# Tweets downloaded: 1377
# Tweets downloaded: 1378
# Tweets downloaded: 1379
# Tweets downloaded: 1380
# Tweets downloaded: 1381
# Tweets downloaded: 1382
# Tweets downloaded: 1383
# Tweets downloaded: 1384
# Tweets downloaded: 1385
# Tweets downloaded: 1386
# Tweets downloaded: 1387
# Tweets downloaded: 1388
# Tweets downloaded: 1389
# Tweets downloaded: 1390
# Tweets downloaded: 1391
# Tweets downloaded: 1392
# Tweets downloaded: 1393
# Tweets downloaded: 1394
# Tweets downloaded: 1395
# Tweets downloaded: 1396
# Tweets downloaded: 1397
# Tweets downloaded: 1398
# Tweets downloaded: 1399
# Tweets downloaded: 1400
# Tweets downloaded: 1401
# Tweets downloaded: 1402
# Tweets downloaded: 1403
# Tweets downloaded: 1404
# Tweets downloaded: 1405
# Tweets downloaded: 1406
# Tweets downloaded: 1407
# Tweets downloaded: 1408
# Tweets downloaded: 1409
# Tweets downloaded: 1410
# Tweets downloaded: 1411
# Tweets downloaded: 1412
# Tweets downloaded: 1413
# Tweets downloaded: 1414
# Tweets downloaded: 1415
# Tweets downloaded: 1416
# Tweets downloaded: 1417
# Tweets downloaded: 1418
# Tweets downloaded: 1419
# Tweets downloaded: 1420
# Tweets downloaded: 1421
# Tweets downloaded: 1422
# Tweets downloaded: 1423
# Tweets downloaded: 1424
# Tweets downloaded: 1425
# Tweets downloaded: 1426
# Tweets downloaded: 1427
# Tweets downloaded: 1428
# Tweets downloaded: 1429
# Tweets downloaded: 1430
# Tweets downloaded: 1431
# Tweets downloaded: 1432
# Tweets downloaded: 1433
# Tweets downloaded: 1434
# Tweets downloaded: 1435
# Tweets downloaded: 1436
# Tweets downloaded: 1437
# Tweets downloaded: 1438
# Tweets downloaded: 1439
# Tweets downloaded: 1440
# Tweets downloaded: 1441
# Tweets downloaded: 1442
# Tweets downloaded: 1443
# Tweets downloaded: 1444
# Tweets downloaded: 1445
# Tweets downloaded: 1446
# Tweets downloaded: 1447
# Tweets downloaded: 1448
# Tweets downloaded: 1449
# Tweets downloaded: 1450
# Tweets downloaded: 1451
# Tweets downloaded: 1452
# Tweets downloaded: 1453
# Tweets downloaded: 1454
# Tweets downloaded: 1455
# Tweets downloaded: 1456
# Tweets downloaded: 1457
# Tweets downloaded: 1458
# Tweets downloaded: 1459
# Tweets downloaded: 1460
# Tweets downloaded: 1461
# Tweets downloaded: 1462
# Tweets downloaded: 1463
# Tweets downloaded: 1464
# Tweets downloaded: 1465
# Tweets downloaded: 1466
# Tweets downloaded: 1467
# Tweets downloaded: 1468
# Tweets downloaded: 1469
# Tweets downloaded: 1470
# Tweets downloaded: 1471
# Tweets downloaded: 1472
# Tweets downloaded: 1473
# Tweets downloaded: 1474
# Tweets downloaded: 1475
# Tweets downloaded: 1476
# Tweets downloaded: 1477
# Tweets downloaded: 1478
# Tweets downloaded: 1479
# Tweets downloaded: 1480
# Tweets downloaded: 1481
# Tweets downloaded: 1482
# Tweets downloaded: 1483
# Tweets downloaded: 1484
# Tweets downloaded: 1485
# Tweets downloaded: 1486
# Tweets downloaded: 1487
# Tweets downloaded: 1488
# Tweets downloaded: 1489
# Tweets downloaded: 1490
# Tweets downloaded: 1491
# Tweets downloaded: 1492
# Tweets downloaded: 1493
# Tweets downloaded: 1494
# Tweets downloaded: 1495
# Tweets downloaded: 1496
# Tweets downloaded: 1497
# Tweets downloaded: 1498
# Tweets downloaded: 1499
# Tweets downloaded: 1500
# Tweets downloaded: 1501
# Tweets downloaded: 1502
# Tweets downloaded: 1503
# Tweets downloaded: 1504
# Tweets downloaded: 1505
# Tweets downloaded: 1506
# Tweets downloaded: 1507
# Tweets downloaded: 1508
# Tweets downloaded: 1509
# Tweets downloaded: 1510
# Tweets downloaded: 1511
# Tweets downloaded: 1512
# Tweets downloaded: 1513
# Tweets downloaded: 1514
# Tweets downloaded: 1515
# Tweets downloaded: 1516
# Tweets downloaded: 1517
# Tweets downloaded: 1518
# Tweets downloaded: 1519
# Tweets downloaded: 1520
# Tweets downloaded: 1521
# Tweets downloaded: 1522
# Tweets downloaded: 1523
# Tweets downloaded: 1524
# Tweets downloaded: 1525
# Tweets downloaded: 1526
# Tweets downloaded: 1527
# Tweets downloaded: 1528
# Tweets downloaded: 1529
# Tweets downloaded: 1530
# Tweets downloaded: 1531
# Tweets downloaded: 1532
# Tweets downloaded: 1533
# Tweets downloaded: 1534
# Tweets downloaded: 1535
# Tweets downloaded: 1536
# Tweets downloaded: 1537
# Tweets downloaded: 1538
# Tweets downloaded: 1539
# Tweets downloaded: 1540
# Tweets downloaded: 1541
# Tweets downloaded: 1542
# Tweets downloaded: 1543
# Tweets downloaded: 1544
# Tweets downloaded: 1545
# Tweets downloaded: 1546
# Tweets downloaded: 1547
# Tweets downloaded: 1548
# Tweets downloaded: 1549
# Tweets downloaded: 1550
# Tweets downloaded: 1551
# Tweets downloaded: 1552
# Tweets downloaded: 1553
# Tweets downloaded: 1554
# Tweets downloaded: 1555
# Tweets downloaded: 1556
# Tweets downloaded: 1557
# Tweets downloaded: 1558
# Tweets downloaded: 1559
# Tweets downloaded: 1560
# Tweets downloaded: 1561
# Tweets downloaded: 1562
# Tweets downloaded: 1563
# Tweets downloaded: 1564
# Tweets downloaded: 1565
# Tweets downloaded: 1566
# Tweets downloaded: 1567
# Tweets downloaded: 1568
# Tweets downloaded: 1569
# Tweets downloaded: 1570
# Tweets downloaded: 1571
# Tweets downloaded: 1572
# Tweets downloaded: 1573
# Tweets downloaded: 1574
# Tweets downloaded: 1575
# Tweets downloaded: 1576
# Tweets downloaded: 1577
# Tweets downloaded: 1578
# Tweets downloaded: 1579
# Tweets downloaded: 1580
# Tweets downloaded: 1581
# Tweets downloaded: 1582
# Tweets downloaded: 1583
# Tweets downloaded: 1584
# Tweets downloaded: 1585
# Tweets downloaded: 1586
# Tweets downloaded: 1587
# Tweets downloaded: 1588
# Tweets downloaded: 1589
# Tweets downloaded: 1590
# Tweets downloaded: 1591
# Tweets downloaded: 1592
# Tweets downloaded: 1593
# Tweets downloaded: 1594
# Tweets downloaded: 1595
# Tweets downloaded: 1596
# Tweets downloaded: 1597
# Tweets downloaded: 1598
# Tweets downloaded: 1599
# Tweets downloaded: 1600
# Tweets downloaded: 1601
# Tweets downloaded: 1602
# Tweets downloaded: 1603
# Tweets downloaded: 1604
# Tweets downloaded: 1605
# Tweets downloaded: 1606
# Tweets downloaded: 1607
# Tweets downloaded: 1608
# Tweets downloaded: 1609
# Tweets downloaded: 1610
# Tweets downloaded: 1611
# Tweets downloaded: 1612
# Tweets downloaded: 1613
# Tweets downloaded: 1614
# Tweets downloaded: 1615
# Tweets downloaded: 1616
# Tweets downloaded: 1617
# Tweets downloaded: 1618
# Tweets downloaded: 1619
# Tweets downloaded: 1620
# Tweets downloaded: 1621
# Tweets downloaded: 1622
# Tweets downloaded: 1623
# Tweets downloaded: 1624
# Tweets downloaded: 1625
# Tweets downloaded: 1626
# Tweets downloaded: 1627
# Tweets downloaded: 1628
# Tweets downloaded: 1629
# Tweets downloaded: 1630
# Tweets downloaded: 1631
# Tweets downloaded: 1632
# Tweets downloaded: 1633
# Tweets downloaded: 1634
# Tweets downloaded: 1635
# Tweets downloaded: 1636
# Tweets downloaded: 1637
# Tweets downloaded: 1638
# Tweets downloaded: 1639
# Tweets downloaded: 1640
# Tweets downloaded: 1641
# Tweets downloaded: 1642
# Tweets downloaded: 1643
# Tweets downloaded: 1644
# Tweets downloaded: 1645
# Tweets downloaded: 1646
# Tweets downloaded: 1647
# Tweets downloaded: 1648
# Tweets downloaded: 1649
# Tweets downloaded: 1650
# Tweets downloaded: 1651
# Tweets downloaded: 1652
# Tweets downloaded: 1653
# Tweets downloaded: 1654
# Tweets downloaded: 1655
# Tweets downloaded: 1656
# Tweets downloaded: 1657
# Tweets downloaded: 1658
# Tweets downloaded: 1659
# Tweets downloaded: 1660
# Tweets downloaded: 1661
# Tweets downloaded: 1662
# Tweets downloaded: 1663
# Tweets downloaded: 1664
# Tweets downloaded: 1665
# Tweets downloaded: 1666
# Tweets downloaded: 1667
# Tweets downloaded: 1668
# Tweets downloaded: 1669
# Tweets downloaded: 1670
# Tweets downloaded: 1671
# Tweets downloaded: 1672
# Tweets downloaded: 1673
# Tweets downloaded: 1674
# Tweets downloaded: 1675
# Tweets downloaded: 1676
# Tweets downloaded: 1677
# Tweets downloaded: 1678
# Tweets downloaded: 1679
# Tweets downloaded: 1680
# Tweets downloaded: 1681
# Tweets downloaded: 1682
# Tweets downloaded: 1683
# Tweets downloaded: 1684
# Tweets downloaded: 1685
# Tweets downloaded: 1686
# Tweets downloaded: 1687
# Tweets downloaded: 1688
# Tweets downloaded: 1689
# Tweets downloaded: 1690
# Tweets downloaded: 1691
# Tweets downloaded: 1692
# Tweets downloaded: 1693
# Tweets downloaded: 1694
# Tweets downloaded: 1695
# Tweets downloaded: 1696
# Tweets downloaded: 1697
# Tweets downloaded: 1698
# Tweets downloaded: 1699
# Tweets downloaded: 1700
# Tweets downloaded: 1701
# Tweets downloaded: 1702
# Tweets downloaded: 1703
# Tweets downloaded: 1704
# Tweets downloaded: 1705
# Tweets downloaded: 1706
# Tweets downloaded: 1707
# Tweets downloaded: 1708
# Tweets downloaded: 1709
# Tweets downloaded: 1710
# Tweets downloaded: 1711
# Tweets downloaded: 1712
# Tweets downloaded: 1713
# Tweets downloaded: 1714
# Tweets downloaded: 1715
# Tweets downloaded: 1716
# Tweets downloaded: 1717
# Tweets downloaded: 1718
# Tweets downloaded: 1719
# Tweets downloaded: 1720
# Tweets downloaded: 1721
# Tweets downloaded: 1722
# Tweets downloaded: 1723
# Tweets downloaded: 1724
# Tweets downloaded: 1725
# Tweets downloaded: 1726
# Tweets downloaded: 1727
# Tweets downloaded: 1728
# Tweets downloaded: 1729
# Tweets downloaded: 1730
# Tweets downloaded: 1731
# Tweets downloaded: 1732
# Tweets downloaded: 1733
# Tweets downloaded: 1734
# Tweets downloaded: 1735
# Tweets downloaded: 1736
# Tweets downloaded: 1737
# Tweets downloaded: 1738
# Tweets downloaded: 1739
# Tweets downloaded: 1740
# Tweets downloaded: 1741
# Tweets downloaded: 1742
# Tweets downloaded: 1743
# Tweets downloaded: 1744
# Tweets downloaded: 1745
# Tweets downloaded: 1746
# Tweets downloaded: 1747
# Tweets downloaded: 1748
# Tweets downloaded: 1749
# Tweets downloaded: 1750
# Tweets downloaded: 1751
# Tweets downloaded: 1752
# Tweets downloaded: 1753
# Tweets downloaded: 1754
# Tweets downloaded: 1755
# Tweets downloaded: 1756
# Tweets downloaded: 1757
# Tweets downloaded: 1758
# Tweets downloaded: 1759
# Tweets downloaded: 1760
# Tweets downloaded: 1761
# Tweets downloaded: 1762
# Tweets downloaded: 1763
# Tweets downloaded: 1764
# Tweets downloaded: 1765
# Tweets downloaded: 1766
# Tweets downloaded: 1767
# Tweets downloaded: 1768
# Tweets downloaded: 1769
# Tweets downloaded: 1770
# Tweets downloaded: 1771
# Tweets downloaded: 1772
# Tweets downloaded: 1773
# Tweets downloaded: 1774
# Tweets downloaded: 1775
# Tweets downloaded: 1776
# Tweets downloaded: 1777
# Tweets downloaded: 1778
# Tweets downloaded: 1779
# Tweets downloaded: 1780
# Tweets downloaded: 1781
# Tweets downloaded: 1782
# Tweets downloaded: 1783
# Tweets downloaded: 1784
# Tweets downloaded: 1785
# Tweets downloaded: 1786
# Tweets downloaded: 1787
# Tweets downloaded: 1788
# Tweets downloaded: 1789
# Tweets downloaded: 1790
# Tweets downloaded: 1791
# Tweets downloaded: 1792
# Tweets downloaded: 1793
# Tweets downloaded: 1794
# Tweets downloaded: 1795
# Tweets downloaded: 1796
# Tweets downloaded: 1797
# Tweets downloaded: 1798
# Tweets downloaded: 1799
# Tweets downloaded: 1800
# Tweets downloaded: 1801
# Tweets downloaded: 1802
# Tweets downloaded: 1803
# Tweets downloaded: 1804
# Tweets downloaded: 1805
# Tweets downloaded: 1806
# Tweets downloaded: 1807
# Tweets downloaded: 1808
# Tweets downloaded: 1809
# Tweets downloaded: 1810
# Tweets downloaded: 1811
# Tweets downloaded: 1812
# Tweets downloaded: 1813
# Tweets downloaded: 1814
# Tweets downloaded: 1815
# Tweets downloaded: 1816
# Tweets downloaded: 1817
# Tweets downloaded: 1818
# Tweets downloaded: 1819
# Tweets downloaded: 1820
# Tweets downloaded: 1821
# Tweets downloaded: 1822
# Tweets downloaded: 1823
# Tweets downloaded: 1824
# Tweets downloaded: 1825
# Tweets downloaded: 1826
# Tweets downloaded: 1827
# Tweets downloaded: 1828
# Tweets downloaded: 1829
# Tweets downloaded: 1830
# Tweets downloaded: 1831
# Tweets downloaded: 1832
# Tweets downloaded: 1833
# Tweets downloaded: 1834
# Tweets downloaded: 1835
# Tweets downloaded: 1836
# Tweets downloaded: 1837
# Tweets downloaded: 1838
# Tweets downloaded: 1839
# Tweets downloaded: 1840
# Tweets downloaded: 1841
# Tweets downloaded: 1842
# Tweets downloaded: 1843
# Tweets downloaded: 1844
# Tweets downloaded: 1845
# Tweets downloaded: 1846
# Tweets downloaded: 1847
# Tweets downloaded: 1848
# Tweets downloaded: 1849
# Tweets downloaded: 1850
# Tweets downloaded: 1851
# Tweets downloaded: 1852
# Tweets downloaded: 1853
# Tweets downloaded: 1854
# Tweets downloaded: 1855
# Tweets downloaded: 1856
# Tweets downloaded: 1857
# Tweets downloaded: 1858
# Tweets downloaded: 1859
# Tweets downloaded: 1860
# Tweets downloaded: 1861
# Tweets downloaded: 1862
# Tweets downloaded: 1863
# Tweets downloaded: 1864
# Tweets downloaded: 1865
# Tweets downloaded: 1866
# Tweets downloaded: 1867
# Tweets downloaded: 1868
# Tweets downloaded: 1869
# Tweets downloaded: 1870
# Tweets downloaded: 1871
# Tweets downloaded: 1872
# Tweets downloaded: 1873
# Tweets downloaded: 1874
# Tweets downloaded: 1875
# Tweets downloaded: 1876
# Tweets downloaded: 1877
# Tweets downloaded: 1878
# Tweets downloaded: 1879
# Tweets downloaded: 1880
# Tweets downloaded: 1881
# Tweets downloaded: 1882
# Tweets downloaded: 1883
# Tweets downloaded: 1884
# Tweets downloaded: 1885
# Tweets downloaded: 1886
# Tweets downloaded: 1887
# Tweets downloaded: 1888
# Tweets downloaded: 1889
# Tweets downloaded: 1890
# Tweets downloaded: 1891
# Tweets downloaded: 1892
# Tweets downloaded: 1893
# Tweets downloaded: 1894
# Tweets downloaded: 1895
# Tweets downloaded: 1896
# Tweets downloaded: 1897
# Tweets downloaded: 1898
# Tweets downloaded: 1899
# Tweets downloaded: 1900
# Tweets downloaded: 1901
# Tweets downloaded: 1902
# Tweets downloaded: 1903
# Tweets downloaded: 1904
# Tweets downloaded: 1905
# Tweets downloaded: 1906
# Tweets downloaded: 1907
# Tweets downloaded: 1908
# Tweets downloaded: 1909
# Tweets downloaded: 1910
# Tweets downloaded: 1911
# Tweets downloaded: 1912
# Tweets downloaded: 1913
# Tweets downloaded: 1914
# Tweets downloaded: 1915
# Tweets downloaded: 1916
# Tweets downloaded: 1917
# Tweets downloaded: 1918
# Tweets downloaded: 1919
# Tweets downloaded: 1920
# Tweets downloaded: 1921
# Tweets downloaded: 1922
# Tweets downloaded: 1923
# Tweets downloaded: 1924
# Tweets downloaded: 1925
# Tweets downloaded: 1926
# Tweets downloaded: 1927
# Tweets downloaded: 1928
# Tweets downloaded: 1929
# Tweets downloaded: 1930
# Tweets downloaded: 1931
# Tweets downloaded: 1932
# Tweets downloaded: 1933
# Tweets downloaded: 1934
# Tweets downloaded: 1935
# Tweets downloaded: 1936
# Tweets downloaded: 1937
# Tweets downloaded: 1938
# Tweets downloaded: 1939
# Tweets downloaded: 1940
# Tweets downloaded: 1941
# Tweets downloaded: 1942
# Tweets downloaded: 1943
# Tweets downloaded: 1944
# Tweets downloaded: 1945
# Tweets downloaded: 1946
# Tweets downloaded: 1947
# Tweets downloaded: 1948
# Tweets downloaded: 1949
# Tweets downloaded: 1950
# Tweets downloaded: 1951
# Tweets downloaded: 1952
# Tweets downloaded: 1953
# Tweets downloaded: 1954
# Tweets downloaded: 1955
# Tweets downloaded: 1956
# Tweets downloaded: 1957
# Tweets downloaded: 1958
# Tweets downloaded: 1959
# Tweets downloaded: 1960
# Tweets downloaded: 1961
# Tweets downloaded: 1962
# Tweets downloaded: 1963
# Tweets downloaded: 1964
# Tweets downloaded: 1965
# Tweets downloaded: 1966
# Tweets downloaded: 1967
# Tweets downloaded: 1968
# Tweets downloaded: 1969
# Tweets downloaded: 1970
# Tweets downloaded: 1971
# Tweets downloaded: 1972
# Tweets downloaded: 1973
# Tweets downloaded: 1974
# Tweets downloaded: 1975
# Tweets downloaded: 1976
# Tweets downloaded: 1977
# Tweets downloaded: 1978
# Tweets downloaded: 1979
# Tweets downloaded: 1980
# Tweets downloaded: 1981
# Tweets downloaded: 1982
# Tweets downloaded: 1983
# Tweets downloaded: 1984
# Tweets downloaded: 1985
# Tweets downloaded: 1986
# Tweets downloaded: 1987
# Tweets downloaded: 1988
# Tweets downloaded: 1989
# Tweets downloaded: 1990
# Tweets downloaded: 1991
# Tweets downloaded: 1992
# Tweets downloaded: 1993
# Tweets downloaded: 1994
# Tweets downloaded: 1995
# Tweets downloaded: 1996
# Tweets downloaded: 1997
# Tweets downloaded: 1998
# Tweets downloaded: 1999()

# %%
tm.df.head()
# Out:
#              timestamp                                              tweet
# 0  2014-28-11 22:28:52  RT @freakonometrics: 'Personality, Gender, and...
# 1  2014-28-11 22:18:33  A short overview about 'How to quickly turn an...
# 2  2014-28-11 18:13:14  RT @vmirly: A great resource for Bayesian Meth...
# 3  2014-27-11 06:00:01  @sirishasun thanks! There is a light at the en...
# 4  2014-27-11 03:52:58  @AnthonyNystrom I don't know exactly what it i...

# %% [markdown]
# If the `twitter_timeline.py` script was executed terminal, you can read the "tweets" from the CSV file via
#
#     import pandas as pd
#     df = pd.read_csv('path/to/CSV')

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## B. Creating the Word Cloud

# %% [markdown]
# [[back to top](#Sections)]

# %% [markdown]
# Now that we collected the tweets from our twitter timeline the creation of the word cloud is pretty simple and straightforward thanks to the nice `wordcloud` module.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# join tweets to a single string
words = ' '.join(tm.df['tweet'])

# remove URLs, RTs, and twitter handles
no_urls_no_tags = " ".join([word for word in words.split() 
                            if 'http' not in word 
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

wordcloud = WordCloud( 
                      font_path='/Users/sebastian/Library/Fonts/CabinSketch-Bold.ttf',
                      stopwords=STOPWORDS,
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(no_urls_no_tags)

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('./my_twitter_wordcloud_1.png', dpi=300)
plt.show()

# %% [markdown]
# Surprise, surprise: The most common term I used in my tweets is obviously "Python!"

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# To make the word cloud even more visually appealing, let us as a custom shape in form of the twitter logo:

# %%
from scipy.misc import imread

twitter_mask = imread('./twitter_mask.png', flatten=True)


wordcloud = WordCloud( 
                      font_path='/Users/sebastian/Library/Fonts/CabinSketch-Bold.ttf',
                      stopwords=STOPWORDS,
                      background_color='white',
                      width=1800,
                      height=1400,
                      mask=twitter_mask
            ).generate(no_urls_no_tags)

plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('./my_twitter_wordcloud_2.png', dpi=300)
plt.show()

# %% [markdown]
# (You can find the `twitter_mask.png` [here](https://raw.githubusercontent.com/rasbt/datacollect/master/dataviz/twitter_cloud/twitter_mask.png))
