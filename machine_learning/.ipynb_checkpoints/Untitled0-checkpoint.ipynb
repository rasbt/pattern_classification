# %% [markdown]
# # Importing a the dataset

# %% [markdown]
# Wine Data Set from the UCI machine learning repository (http://archive.ics.uci.edu/ml/datasets/Wine)
#
# Forina, M. et al, PARVUS - An Extendible Package for Data
#        Exploration, Classification and Correlation. Institute of Pharmaceutical
#        and Food Analysis and Technologies, Via Brigata Salerno,
#        16147 Genoa, Italy.

# %%
from sklearn import datasets
iris = datasets.load_iris()
X_iris, y_iris = iris.data, iris.target

# %%
X_iris
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
# ...

# %% [markdown]
# This is a dataset consisting of 3 different classes where each row correspond to a particular wine sample.
#
# The class labels (1, 2, 3) are listed in the first column, and the columns 2-14 correspond to the following 13 attributes:
#
# 1) Alcohol
# 2) Malic acid
# 3) Ash
# 4) Alcalinity of ash
# 5) Magnesium
# 6) Total phenols
# 7) Flavanoids
# 8) Nonflavanoid phenols
# 9) Proanthocyanins
# 10) Color intensity
# 11) Hue
# 12) OD280/OD315 of diluted wines
# 13) Proline
#
# Excerpt from the wine_data.csv dataset:
#
# <pre>1,14.23,1.71,2.43,15.6,127,2.8,3.06,.28,2.29,5.64,1.04,3.92,1065
# 1,13.2,1.78,2.14,11.2,100,2.65,2.76,.26,1.28,4.38,1.05,3.4,1050
# [...]
# 2,12.37,.94,1.36,10.6,88,1.98,.57,.28,.42,1.95,1.05,1.82,520
# 2,12.33,1.1,2.28,16,101,2.05,1.09,.63,.41,3.27,1.25,1.67,680
# [...]
# 3,12.86,1.35,2.32,18,122,1.51,1.25,.21,.94,4.1,.76,1.29,630
# 3,12.88,2.99,2.4,20,104,1.3,1.22,.24,.83,5.4,.74,1.42,530</pre>

# %%
import numpy as np

# load class labels from column 1
y_wine = np.loadtxt(open("../data/wine_data.csv","rb"), 
        delimiter=",", skiprows=0, usecols=range(1))

# load the 13 attributes
X_wine = np.loadtxt(open("../data/wine_data.csv","rb"), 
        delimiter=",", skiprows=0, usecols=range(1,14))

# print 1st wine sample
float_formatter = lambda x: '{%.2f}'.format(x)
np.set_printoptions(formatter={'float_kind':float_formatter})
print('Class label:{:}\n{:}'.format(y_wine[0], X_wine[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-394b5daef11f> in <module>()
#      10
#      11 # print 1st wine sample
# ---> 12 np.set_printoptions(formatter={'float_kind':float_formatter})
#      13 print('Class label:{:}\n{:}'.format(y_wine[0], X_wine[0]))
#
# NameError: name 'float_formatter' is not defined

# %%
wine_data[1]
# Out:
# array([ 1.71,  1.78,  2.36,  1.95,  2.59,  1.76,  1.87,  2.15,  1.64,
#         1.35,  2.16,  1.48,  1.73,  1.73,  1.87,  1.81,  1.92,  1.57,
#         1.59,  3.1 ,  1.63,  3.8 ,  1.86,  1.6 ,  1.81,  2.05,  1.77,
#         1.72,  1.9 ,  1.68,  1.5 ,  1.66,  1.83,  1.53,  1.8 ,  1.81,
#         1.64,  1.65,  1.5 ,  3.99,  1.71,  3.84,  1.89,  3.98,  1.77,
#         4.04,  3.59,  1.68,  2.02,  1.73,  1.73,  1.65,  1.75,  1.9 ,
#         1.67,  1.73,  1.7 ,  1.97,  1.43,  0.94,  1.1 ,  1.36,  1.25,
#         1.13,  1.45,  1.21,  1.01,  1.17,  0.94,  1.19,  1.61,  1.51,
#         1.66,  1.67,  1.09,  1.88,  0.9 ,  2.89,  0.99,  3.87,  0.92,
#         1.81,  1.13,  3.86,  0.89,  0.98,  1.61,  1.67,  2.06,  1.33,
#         1.83,  1.51,  1.53,  2.83,  1.99,  1.52,  2.12,  1.41,  1.07,
#         3.17,  2.08,  1.34,  2.45,  1.72,  1.73,  2.55,  1.73,  1.75,
#         1.29,  1.35,  3.74,  2.43,  2.68,  0.74,  1.39,  1.51,  1.47,
# ...
